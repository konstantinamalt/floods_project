# %% [markdown]
# # Create the decades dataset

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # The columns we want all three excels to have in this order:
# "id", "flood_name", "flood_info", "year", "country", "start_date", "end_date", "fatalities", "people_affected",
#     "nuts3_region", "nuts3_code", "nuts3_region_urban_rural_typology",
#     "nuts3_coastal_regions", "nuts2_region", "nuts2_code", "nuts1_region", "nuts1_code", "cause", "flood_type", "data_exists",
#     "sources", "notes", "reportLink"

# %% [markdown]
# # Fixing the Copernicus 2024-2023 dataset to concatinate with the others later, we want same columns

# %% [markdown]
# ### first fix the nuts2 names after checking they are inconsistent

# %%
df = pd.read_excel("CLEAN_FINAL_aois_all_details_nuts_translated.xlsx")

# %%
nuts2_english = {
    'Valencian Community': 'Valencia region',
    'Castilla-La Mancha region': 'Castilla-La Mancha region',
    'Emilia-Romagna region': 'Emilia-Romagna region',
    'Pannonian Croatia region': 'Pannonian Croatia region',
    'Lower Austria State': 'Lower Austria region',
    'Dresden region': 'Dresden region',
    'Western Slovakia': 'Western Slovakia region',
    'Central Transdanubia region': 'Central Transdanubia region',
    'South-Eastern region of Romania': 'South-Eastern Romania region',
    'Bratislava region': 'Bratislava region',
    'Lower Silesian voivodeship': 'Lower Silesia region',
    'Silesian voivodeship': 'Silesia region',
    'Moravian-Silesian region': 'Moravian-Silesia region',
    'Opole voivodeship': 'Opole region',
    'Lubusz voivodeship': 'Lubusz region',
    'Łódź voivodeship': 'Łódź region',
    'Brandenburg state': 'Brandenburg region',
    'Upper Palatinate': 'Upper Palatinate region',
    'Stuttgart Region': 'Stuttgart region',
    'Upper Palatinate region': 'Upper Palatinate region',  # Ensuring consistency
    'Lower Bavaria region': 'Lower Bavaria region',
    'Upper Bavaria region': 'Upper Bavaria region',
    'Swabia region': 'Swabia region',
    'Upper Norrland region': 'Upper Norrland region',
    'Saarland': 'Saarland region',
    'Lombardy region': 'Lombardy region',
    'Northern and Western region of Ireland': 'Northern and Western Ireland region',
    'Saxony-Anhalt': 'Saxony-Anhalt region',
    'Poitou-Charentes region': 'Poitou-Charentes region',
    'West Flanders province': 'West Flanders region',
    'Nord-Pas de Calais region': 'Nord-Pas de Calais region',
    'Tuscany region': 'Tuscany region',
    'Sterea Ellada region': 'Sterea Ellada region',
    'Community of Madrid': 'Madrid region',
    'Thessaly region': 'Thessaly region',
    'Eastern Central Sweden': 'Eastern Central Sweden region',
    'Northern Central Sweden': 'Northern Central Sweden region',
    'Eastern Slovenia': 'Eastern Slovenia region',
    'Western Slovenia': 'Western Slovenia region'
}

# %%
df["nuts2_name_2024_en"] = df["nuts2_name_2024_en"].apply(lambda x: nuts2_english.get(x, x))

# %%
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("New Aquitaine", "Nouvelle-Aquitaine")
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("Macroregion two", "Macroregion two (Romania)")
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("South-Western macroregion", "South-Western Poland macroregion")
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("Southern Macroregion", "Southern Poland Macroregion")
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("North-Western macroregion", "North-Western Poland macroregion")
df["nuts1_name_2024_en"] = df["nuts1_name_2024_en"].replace("Central macroregion", "Central Poland macroregion")

# %%
df['nuts1_name_2024_en'].unique()
# Out:
# array(['Eastern Spain', 'Central Spain', 'North-Eastern Italy', 'Croatia',
#        'Eastern Austria', 'Brandenburg', 'Saxony', 'Slovakia',
#        'Transdanubia', 'Macroregion two (Romania)',
#        'South-Western Poland macroregion', 'Southern Poland Macroregion',
#        'Czechia', 'North-Western Poland macroregion',
#        'Central Poland macroregion', 'Bavaria', 'Baden-Württemberg',
#        'Northern Sweden', 'Saarland', 'North-Western Italy', 'Ireland',
#        'Lower Saxony', 'Saxony-Anhalt', 'Nouvelle-Aquitaine',
#        'Flemish Region', 'Hauts-de-France', 'Central Italy',
#        'Central Greece', 'Madrid region', 'Eastern Sweden', 'Slovenia',
#        'Latvia'], dtype=object)

# %%
df.to_excel("CLEAN_FINAL_aois_all_details_nuts_translated.xlsx", index=False)

# %% [markdown]
# #### now continue..

# %%
df = pd.read_excel("CLEAN_FINAL_aois_all_details_nuts_translated.xlsx")

# %%
df_copernicus_nuts3 = df[[
    "activation_code", "event_name", "reason", "activator", 
    "eventTime", "activationTime", "countries", "nuts3_name_2024", "nuts3_name_2024_en", "nuts3_code_2024", "nuts3_2024_urban_rural_typology", "nuts3_2024_coastal_regions",
    "nuts2_name_2024_en", "nuts2_code_2024", "nuts1_name_2024_en", "nuts1_code_2024"
]].drop_duplicates(subset='nuts3_name_2024').reset_index(drop=True)
df_copernicus_nuts3
# Out:
#    activation_code                             event_name  \
# 0          EMSR773        Flood in Valencia Region, Spain
# 1          EMSR773        Flood in Valencia Region, Spain
# 2          EMSR773        Flood in Valencia Region, Spain
# 3          EMSR771        Flood in Emilia- Romagna, Italy
# 4          EMSR771        Flood in Emilia- Romagna, Italy
# ..             ...                                    ...
# 63         EMSR680                      Flood in Slovenia
# 64         EMSR680                      Flood in Slovenia
# 65         EMSR680                      Flood in Slovenia
# 66         EMSR664                         Flood in Italy
# 67         EMSR657  Flood in Daugava River valley, Latvia
#
#                                                reason  \
# 0   On 29 October 2024 at 14:30 UTC, an extraordin...
# 1   On 29 October 2024 at 14:30 UTC, an extraordin...
# 2   On 29 October 2024 at 14:30 UTC, an extraordin...
# 3   Italy has been hit in recent days by a severe ...
# 4   Italy has been hit in recent days by a severe ...
# ..                                                ...
# 63  The Slovenian Environment Agency (ARSO) has is...
# 64  The Slovenian Environment Agency (ARSO) has is...
# 65  The Slovenian Environment Agency (ARSO) has is...
# 66  A new wave of severe weather has again hit sou...
# 67  As of 30 March 2023 a flood due to melted snow...
#
#                                             activator            eventTime  \
# 0   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 1   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 2   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 3   Italy|Presidency of the Council of Ministers -...  2024-10-20T12:00:00
# 4   Italy|Presidency of the Council of Ministers -...  2024-10-20T12:00:00
# ..                                                ...                  ...
# 63  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 64  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 65  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 66  Italy|Presidenza del Consiglio dei Ministri - ...  2023-05-16T11:00:00
# 67       Latvia|Latvian State Fire and Rescue Service  2023-03-30T00:00:00
#
#          activationTime countries     nuts3_name_2024      nuts3_name_2024_en  \
# 0   2024-10-29T16:40:00     Spain            Valencia      Valencia province
# 1   2024-10-29T16:40:00     Spain            Albacete       Albacete province
# 2   2024-10-29T16:40:00     Spain           Castellón      Castellón province
# 3   2024-10-20T08:24:00     Italy  Reggio nell'Emilia  Reggio Emilia province
# 4   2024-10-20T08:24:00     Italy              Modena         Modena province
# ..                  ...       ...                 ...                     ...
# 63  2023-08-04T10:40:00  Slovenia           Savinjska          Savinja region
# 64  2023-08-04T10:40:00  Slovenia            Pomurska          Pomurje region
# 65  2023-08-04T10:40:00  Slovenia           Gorenjska   Upper Carniola region
# 66  2023-05-16T14:33:00     Italy        Forlì-Cesena   Forlì-Cesena province
# 67  2023-03-31T11:49:00    Latvia           Latvija *                     NaN
#
#    nuts3_code_2024 nuts3_2024_urban_rural_typology nuts3_2024_coastal_regions  \
# 0            ES523             predominantly urban                    coastal
# 1            ES421                    intermediate                non-coastal
# 2            ES522                    intermediate                    coastal
# 3            ITH53                    intermediate                non-coastal
# 4            ITH54                    intermediate                non-coastal
# ..             ...                             ...                        ...
# 63           SI034             predominantly rural                non-coastal
# 64           SI031             predominantly rural                non-coastal
# 65           SI042                    intermediate                non-coastal
# 66           ITH58                    intermediate                    coastal
# 67             NaN                             NaN                        NaN
#
#            nuts2_name_2024_en nuts2_code_2024   nuts1_name_2024_en  \
# 0             Valencia region            ES52        Eastern Spain
# 1   Castilla-La Mancha region            ES42        Central Spain
# 2             Valencia region            ES52        Eastern Spain
# 3       Emilia-Romagna region            ITH5  North-Eastern Italy
# 4       Emilia-Romagna region            ITH5  North-Eastern Italy
# ..                        ...             ...                  ...
# 63    Eastern Slovenia region            SI03             Slovenia
# 64    Eastern Slovenia region            SI03             Slovenia
# 65    Western Slovenia region            SI04             Slovenia
# 66      Emilia-Romagna region            ITH5  North-Eastern Italy
# 67                        NaN             NaN               Latvia
#
#    nuts1_code_2024
# 0              ES5
# 1              ES4
# 2              ES5
# 3              ITH
# 4              ITH
# ..             ...
# 63             SI0
# 64             SI0
# 65             SI0
# 66             ITH
# 67             LV0
#
# [68 rows x 16 columns]

# %% [markdown]
# ## You have wrong event_names in the above dataset. You decided you're going to include dates as well
# ## merge it with the one you created for sums per flood and fixed the names manually

# %%
df_per_flood = pd.read_excel("general_copernicus_sums_categories_per_event_new.xlsx")
df_per_flood
# Out:
#    activation_code                                         event_name  \
# 0          EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 1          EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# 2          EMSR768  Flood in Karlovac and Sisak-Moslavina counties...
# 3          EMSR766  Flood in Osijek-Baranja and Vukovar-Syrmia cou...
# 4          EMSR764        Flood in Lower Austria on 14 September 2024
# 5          EMSR763  Flood in Brandenburg, Germany on 22 September ...
# 6          EMSR762  Flood in Emilia-Romagna region, Italy on 18 Se...
# 7          EMSR761  Flood in Dresden region, Germany on 18 Septemb...
# 8          EMSR759  Flood on the Danube in Hungary and Slovakia, o...
# 9          EMSR758  Flood in Galati county, Romania, on 14 Septemb...
# 10         EMSR757  Flood in Bratislava and Trenčín region, Slovak...
# 11         EMSR756  Flood in South West Poland and Czechia, on 14 ...
# 12         EMSR755  Flood in Brandenbourg, Germany on 14 September...
# 13         EMSR728  Flood in Baden-Württemberg and Bavaria, German...
# 14         EMSR725           Flood in Northern Sweden, on 20 May 2024
# 15         EMSR722  Flood in Saarland region, Germany, on 17 May 2024
# 16         EMSR721    Flood in Lombardy region, Italy, on 14 May 2024
# 17         EMSR718     Flood in West Ireland region, on 11 April 2024
# 18         EMSR713  Flood in Saarland region, Germany, on 2 Februa...
# 19         EMSR712  Flood in Lower Saxony and Saxony-Anhalt, Germa...
# 20         EMSR711  Flood in Southwestern France, on 14 December 2023
# 21         EMSR708  Flood in Flemish region, Belgium on 10 Novembe...
# 22         EMSR706       Flood in Northern France, on 7 November 2023
# 23         EMSR705  Flood in Tuscany region, Italy, on 2 November ...
# 24         EMSR697  Flood in Sterea Ellada region, Greece on 27 Se...
# 25         EMSR694  Flood in Madrid and Toledo, Spain on 3 Septemb...
# 26         EMSR692  Flood in Thessaly region, Greece on 5 Septembe...
# 27         EMSR684  Flood in Dalarna and Uppsala counties, Sweden ...
# 28         EMSR680  Flood in Eastern and Western Slovenia, on 4 Au...
# 29         EMSR664  Flood in Emilia-Romagna region, Italy on 16 Ma...
# 30         EMSR659  Flood in Emilia-Romagna region, Italy on 2 May...
# 31         EMSR657  Flood in Daugava River valley, Latvia on 30 Ma...
#
#                                                reason  \
# 0   On 29 October 2024 at 14:30 UTC, an extraordin...
# 1   Italy has been hit in recent days by a severe ...
# 2   On the 4 October 2024 in the afternoon, the pe...
# 3   On the 25 September 2024 at 12:00, top of the ...
# 4   On the 14 September 2024, heavy reain with hug...
# 5   On the 22 September a flood event is forecast ...
# 6   Since the early morning of 18 September 2024, ...
# 7   On September 18 of September 2024 at 13:00 UTC...
# 8   On 13 September 2024, from 06:00 local time, d...
# 9   On 14 September 2024, starting at 05:00 local ...
# 10  Due to heavy rainfall over the coming days, fl...
# 11  Due to heavy rainfall in Middle and Eastern Eu...
# 12  Due to heavy rainfall in Middle and Eastern Eu...
# 13  Starting in the early morning of 31st May 2024...
# 14  High water levels on 20 May 2024 at 18:00 have...
# 15  On 17 May 2024 at 08:00 a flood event was repo...
# 16  On 14 May 2024 at 14:00, an intense weather sy...
# 17  During the evening on 11 April 2024 Lough Funs...
# 18  Due to the currently prevailing flood situatio...
# 19  On the 24 December 2023, flood events are fore...
# 20  On the 14 December 2023 at 12:00, a flood even...
# 21  On 10 November 2023 between 6:00 and 12:00 UTC...
# 22  On the 7 November 2023, flooding is affecting ...
# 23  On the 2 November 2023 during afternoon, an in...
# 24  Following the early warning sent by the Europe...
# 25  As of 03 September at 17:00 slow-moving storm ...
# 26  On 05 September 2023 at 10:30 due to extreme r...
# 27  On the 15 August 2023 there is a risk of flood...
# 28  The Slovenian Environment Agency (ARSO) has is...
# 29  A new wave of severe weather has again hit sou...
# 30  On the 02 May 2023, an intense phase of bad we...
# 31  As of 30 March 2023 a flood due to melted snow...
#
#                                             activator           eventTime  \
# 0   Spain|Ministry of Interior - Centro Nacional d... 2024-10-29 14:30:00
# 1   Italy|Presidency of the Council of Ministers -... 2024-10-20 12:00:00
# 2   Croatia|National Protection and Rescue Directo... 2024-10-04 14:00:00
# 3   Croatia|National Protection and Rescue Directo... 2024-09-25 12:00:00
# 4   EC Services|DG-ECHO, DG DEFIS, DG DEVCO, DG HO... 2024-09-14 12:00:00
# 5   Germany|Bundesamt fur Bevolkerungsschutz und K... 2024-09-22 12:00:00
# 6   Italy|Presidency of the Council of Ministers -... 2024-09-18 06:00:00
# 7                                      Autorised User 2024-09-18 12:00:00
# 8   Hungary|National Directorate General for Disas... 2024-09-13 06:00:00
# 9   Romania|General Inspectorate for Emergency Sit... 2024-09-14 05:00:00
# 10  Slovakia|Ministry of Interior - Section of the... 2024-09-13 15:00:00
# 11  Poland|The National Centre for Coordination of... 2024-09-14 00:00:00
# 12  Germany|Bundesamt fur Bevolkerungsschutz und K... 2024-09-14 12:00:00
# 13  Germany|Gemeinsames Melde- und Lagezentrum von... 2024-05-31 12:00:00
# 14    Sweden|Swedish Civil Contingencies Agency (MSB) 2024-05-20 18:00:00
# 15  Germany|Gemeinsames Melde- und Lagezentrum von... 2024-05-17 08:00:00
# 16  Italy|Presidenza del Consiglio dei Ministri - ... 2024-05-14 14:00:00
# 17  Ireland|National Directorate for Fire and Emer... 2024-04-11 18:00:00
# 18  Germany|Gemeinsames Melde- und Lagezentrum von... 2024-01-02 18:00:00
# 19  Germany|Gemeinsames Melde- und Lagezentrum von... 2023-12-24 08:00:00
# 20  France|Centre Operationnel de Gestion Intermin... 2023-12-14 12:00:00
# 21  Belgium|Centre Gouvernemental de Coordination ... 2023-11-10 06:00:00
# 22  France|Centre Operationnel de Gestion Intermin... 2023-11-07 00:00:00
# 23  Italy|Presidenza del Consiglio dei Ministri - ... 2023-11-02 22:00:00
# 24  Greece|General secretariat for Civil protectio... 2023-09-27 17:00:00
# 25  Spain|Centro de Coordinacion Operativa (CECOP)... 2023-09-03 17:00:00
# 26  Greece|General secretariat for Civil protectio... 2023-09-05 10:30:00
# 27    Sweden|Swedish Civil Contingencies Agency (MSB) 2023-08-15 00:00:00
# 28  Slovenia|Ministry of Defence - Administration ... 2023-08-04 09:00:00
# 29  Italy|Presidenza del Consiglio dei Ministri - ... 2023-05-16 11:00:00
# 30  Italy|Presidenza del Consiglio dei Ministri - ... 2023-05-02 18:00:00
# 31       Latvia|Latvian State Fire and Rescue Service 2023-03-30 00:00:00
#
#         activationTime             countries  \
# 0  2024-10-29 16:40:00                 Spain
# 1  2024-10-20 08:24:00                 Italy
# 2  2024-10-04 09:35:00               Croatia
# 3  2024-09-24 11:53:00               Croatia
# 4  2024-09-22 08:19:00               Austria
# 5  2024-09-20 13:01:00               Germany
# 6  2024-09-18 14:58:00                 Italy
# 7  2024-09-18 13:00:00               Germany
# 8  2024-09-14 15:59:00  Hungary and Slovakia
# 9  2024-09-14 13:44:00               Romania
# 10 2024-09-13 15:59:00              Slovakia
# 11 2024-09-13 12:50:00    Poland and Czechia
# 12 2024-09-13 10:04:00               Germany
# 13 2024-05-30 20:09:00               Germany
# 14 2024-05-20 15:08:00                Sweden
# 15 2024-05-17 16:37:00               Germany
# 16 2024-05-16 15:29:00                 Italy
# 17 2024-04-12 17:34:00               Ireland
# 18 2024-01-03 16:10:00               Germany
# 19 2023-12-22 17:45:00               Germany
# 20 2023-12-14 11:19:00                France
# 21 2023-11-10 11:03:00               Belgium
# 22 2023-11-07 14:48:00                France
# 23 2023-11-03 03:21:00                 Italy
# 24 2023-09-26 10:32:00                Greece
# 25 2023-09-07 09:09:00                 Spain
# 26 2023-09-05 12:10:00                Greece
# 27 2023-08-15 17:45:00                Sweden
# 28 2023-08-04 10:40:00              Slovenia
# 29 2023-05-16 14:33:00                 Italy
# 30 2023-05-03 09:39:00                 Italy
# 31 2023-03-31 11:49:00                Latvia
#
#                                         nuts3_regions  \
# 0   Albacete province, Castellón province, Valenci...
# 1   Bologna province, Ferrara province, Modena pro...
# 2             Karlovac county, Sisak-Moslavina county
# 3        Osijek-Baranja county, Vukovar-Syrmia county
# 4   Lower Austria South region, Mostviertel region...
# 5                                                 NaN
# 6                  Bologna province, Ravenna province
# 7                                                 NaN
# 8              Komárom-Esztergom county, Nitra region
# 9                                       Galați county
# 10                  Bratislava region, Trenčín region
# 11  Jelenia Gora county, Legnica-Głogów Region, Mo...
# 12                              Spree-Neisse district
# 13  Cham District, Donau-Ries District, Landsberg ...
# 14                                  Norrbotten County
# 15                                                NaN
# 16                                     Milan province
# 17                                West Ireland region
# 18                                                NaN
# 19                          Mansfeld-Südharz district
# 20                       Charente-Maritime department
# 21                                  Kortrijk District
# 22                           Pas-de-Calais department
# 23   Florence province, Pisa province, Prato province
# 24                      Evia region, Fthiotida region
# 25                     Madrid region, Toledo province
# 26  Karditsa and Trikala region, Larissa region, M...
# 27                     Dalarna County, Uppsala County
# 28  Carinthia region, Pomurje region, Savinja regi...
# 29  Bologna province, Forlì-Cesena province, Raven...
# 30                 Bologna province, Ravenna province
# 31                                                NaN
#
#                                         nuts2_regions  \
# 0      Castilla-La Mancha region, Valencian Community
# 1                               Emilia-Romagna region
# 2                            Pannonian Croatia region
# 3                            Pannonian Croatia region
# 4                                 Lower Austria State
# 5                                                 NaN
# 6                               Emilia-Romagna region
# 7                                      Dresden region
# 8       Central Transdanubia region, Western Slovakia
# 9                     South-Eastern region of Romania
# 10                Bratislava region, Western Slovakia
# 11  Lower Silesian voivodeship, Lubusz voivodeship...
# 12                                  Brandenburg state
# 13  Lower Bavaria region, Stuttgart Region, Swabia...
# 14                              Upper Norrland region
# 15                                           Saarland
# 16                                    Lombardy region
# 17             Northern and Western region of Ireland
# 18                                           Saarland
# 19                                      Saxony-Anhalt
# 20                            Poitou-Charentes region
# 21                             West Flanders province
# 22                          Nord-Pas de Calais region
# 23                                     Tuscany region
# 24                               Sterea Ellada region
# 25     Castilla-La Mancha region, Community of Madrid
# 26                                    Thessaly region
# 27    Eastern Central Sweden, Northern Central Sweden
# 28                 Eastern Slovenia, Western Slovenia
# 29                              Emilia-Romagna region
# 30                              Emilia-Romagna region
# 31                                                NaN
#
#                                         nuts1_regions event_extent  \
# 0                        Central Spain, Eastern Spain      53287,6
# 1                                 North-Eastern Italy      13351,4
# 2                                             Croatia       2582,2
# 3                                             Croatia       5633,9
# 4                                     Eastern Austria        582,5
# 5                                         Brandenburg       9010,7
# 6                                 North-Eastern Italy       3240,9
# 7                                              Saxony        566,8
# 8                              Slovakia, Transdanubia         5895
# 9                                     Macroregion two        918,4
# 10                                           Slovakia      10330,7
# 11  Central macroregion, Czechia, North-Western ma...      41234,3
# 12                                        Brandenburg        140,9
# 13                         Baden-Württemberg, Bavaria      15026,3
# 14                                    Northern Sweden        191,1
# 15                                           Saarland       1332,4
# 16                                North-Western Italy        127,6
# 17                                            Ireland         42,1
# 18                                           Saarland        131,3
# 19                        Lower Saxony, Saxony-Anhalt      81611,1
# 20                                      New Aquitaine      19515,8
# 21                                     Flemish Region       5561,2
# 22                                    Hauts-de-France        986,9
# 23                                      Central Italy         2796
# 24                                     Central Greece       1093,8
# 25                       Central Spain, Madrid region        688,1
# 26                                     Central Greece     122374,7
# 27                    Eastern Sweden, Northern Sweden        566,2
# 28                                           Slovenia        834,6
# 29                                North-Eastern Italy      17898,7
# 30                                North-Eastern Italy       2562,5
# 31                                             Latvia       7220,5
#
#    agricultural_land natural_ecosystems road_infrastructure  \
# 0            47466,8              967,3              1523,4
# 1             9583,8             1539,9                19,3
# 2             1116,5                  8                 5,4
# 3              605,8             4222,3                 0,6
# 4              529,9               16,4                 2,1
# 5             3984,6             3652,1                 3,7
# 6               2309               34,3                 9,8
# 7                439                0,1                 8,9
# 8             3915,1             1269,5                  77
# 9              784,2               71,5                 2,8
# 10            6096,5              641,6                  64
# 11           29181,3             3544,9               200,5
# 12             131,5                9,5                 0,1
# 13           15233,8              621,7                94,1
# 14             127,2               20,1                   1
# 15            1149,2               63,7                 6,6
# 16              78,7                 23                   3
# 17             181,4                 27                 0,5
# 18             119,2               61,2                 2,7
# 19             56071             2179,7               106,4
# 20            3907,7             1762,1                 6,7
# 21            4976,7               46,9                 9,7
# 22            1756,8              485,7                 9,6
# 23              2545               65,4                  11
# 24             769,4              253,5                 2,6
# 25             426,3              236,4                 2,9
# 26          113301,2             1760,6                1590
# 27              65,4              395,8                 0,5
# 28             604,7              134,1                16,6
# 29           11118,7               53,8                31,1
# 30            2458,6               81,2                 9,2
# 31            6631,3              427,1                29,7
#
#    railway_infrastructure pipelines_and_communication_infrastructure  \
# 0                    99,4                                      277,1
# 1                     0,6                                       34,3
# 2                     0,2                                        3,1
# 3                     NaN                                        0,6
# 4                     0,2                                        NaN
# 5                     0,1                                        0,7
# 6                     1,4                                       10,7
# 7                     4,6                                          7
# 8                     8,2                                       51,8
# 9                     0,6                                          1
# 10                    5,1                                       38,8
# 11                   16,2                                      154,6
# 12                    0,1                                        NaN
# 13                    6,8                                      119,6
# 14                    NaN                                        NaN
# 15                    2,3                                       17,9
# 16                    NaN                                        NaN
# 17                    NaN                                        0,1
# 18                    0,1                                        4,2
# 19                   31,1                                      178,1
# 20                      8                                       35,2
# 21                    0,2                                       12,7
# 22                    2,5                                       11,2
# 23                    0,9                                       22,8
# 24                    0,2                                        0,4
# 25                    0,4                                        NaN
# 26                  148,8                                      127,5
# 27                    NaN                                        1,5
# 28                    0,6                                        4,5
# 29                    0,9                                       55,5
# 30                    0,2                                        9,1
# 31                      1                                       43,6
#
#    residential_buildings_hectares  population_affected
# 0                           656,7               190090
# 1                             6,4                  670
# 2                             2,8                  350
# 3                               2                   20
# 4                             NaN                  350
# 5                             0,5                  100
# 6                             0,5                  420
# 7                             0,7                 1500
# 8                            96,4                 3000
# 9                             9,9                   60
# 10                             21                  820
# 11                          314,3                11300
# 12                            NaN                   10
# 13                           22,5                 3200
# 14                            NaN                   20
# 15                            2,6                  230
# 16                            NaN                  350
# 17                            NaN                  200
# 18                            NaN                  150
# 19                           74,1                37400
# 20                           19,3                 1400
# 21                            NaN                  650
# 22                           57,8                 6600
# 23                            2,7                 5000
# 24                            1,1                  120
# 25                            NaN                  700
# 26                         3121,9                44000
# 27                            NaN                   50
# 28                            1,6                 1280
# 29                           10,3                 9250
# 30                            NaN                  820
# 31                            2,7                  450

# %%
df_copernicus_nuts3 = df_copernicus_nuts3.merge(df_per_flood, on="activation_code", how="left")
df_copernicus_nuts3
# Out:
#    activation_code                           event_name_x  \
# 0          EMSR773        Flood in Valencia Region, Spain
# 1          EMSR773        Flood in Valencia Region, Spain
# 2          EMSR773        Flood in Valencia Region, Spain
# 3          EMSR771        Flood in Emilia- Romagna, Italy
# 4          EMSR771        Flood in Emilia- Romagna, Italy
# ..             ...                                    ...
# 63         EMSR680                      Flood in Slovenia
# 64         EMSR680                      Flood in Slovenia
# 65         EMSR680                      Flood in Slovenia
# 66         EMSR664                         Flood in Italy
# 67         EMSR657  Flood in Daugava River valley, Latvia
#
#                                              reason_x  \
# 0   On 29 October 2024 at 14:30 UTC, an extraordin...
# 1   On 29 October 2024 at 14:30 UTC, an extraordin...
# 2   On 29 October 2024 at 14:30 UTC, an extraordin...
# 3   Italy has been hit in recent days by a severe ...
# 4   Italy has been hit in recent days by a severe ...
# ..                                                ...
# 63  The Slovenian Environment Agency (ARSO) has is...
# 64  The Slovenian Environment Agency (ARSO) has is...
# 65  The Slovenian Environment Agency (ARSO) has is...
# 66  A new wave of severe weather has again hit sou...
# 67  As of 30 March 2023 a flood due to melted snow...
#
#                                           activator_x          eventTime_x  \
# 0   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 1   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 2   Spain|Ministry of Interior - Centro Nacional d...  2024-10-29T14:30:00
# 3   Italy|Presidency of the Council of Ministers -...  2024-10-20T12:00:00
# 4   Italy|Presidency of the Council of Ministers -...  2024-10-20T12:00:00
# ..                                                ...                  ...
# 63  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 64  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 65  Slovenia|Ministry of Defence - Administration ...  2023-08-04T09:00:00
# 66  Italy|Presidenza del Consiglio dei Ministri - ...  2023-05-16T11:00:00
# 67       Latvia|Latvian State Fire and Rescue Service  2023-03-30T00:00:00
#
#        activationTime_x countries_x     nuts3_name_2024  \
# 0   2024-10-29T16:40:00       Spain            Valencia
# 1   2024-10-29T16:40:00       Spain            Albacete
# 2   2024-10-29T16:40:00       Spain           Castellón
# 3   2024-10-20T08:24:00       Italy  Reggio nell'Emilia
# 4   2024-10-20T08:24:00       Italy              Modena
# ..                  ...         ...                 ...
# 63  2023-08-04T10:40:00    Slovenia           Savinjska
# 64  2023-08-04T10:40:00    Slovenia            Pomurska
# 65  2023-08-04T10:40:00    Slovenia           Gorenjska
# 66  2023-05-16T14:33:00       Italy        Forlì-Cesena
# 67  2023-03-31T11:49:00      Latvia           Latvija *
#
#         nuts3_name_2024_en nuts3_code_2024  ...  \
# 0       Valencia province            ES523  ...
# 1        Albacete province           ES421  ...
# 2       Castellón province           ES522  ...
# 3   Reggio Emilia province           ITH53  ...
# 4          Modena province           ITH54  ...
# ..                     ...             ...  ...
# 63          Savinja region           SI034  ...
# 64          Pomurje region           SI031  ...
# 65   Upper Carniola region           SI042  ...
# 66   Forlì-Cesena province           ITH58  ...
# 67                     NaN             NaN  ...
#
#                                      nuts2_regions  \
# 0   Castilla-La Mancha region, Valencian Community
# 1   Castilla-La Mancha region, Valencian Community
# 2   Castilla-La Mancha region, Valencian Community
# 3                            Emilia-Romagna region
# 4                            Emilia-Romagna region
# ..                                             ...
# 63              Eastern Slovenia, Western Slovenia
# 64              Eastern Slovenia, Western Slovenia
# 65              Eastern Slovenia, Western Slovenia
# 66                           Emilia-Romagna region
# 67                                             NaN
#
#                    nuts1_regions event_extent agricultural_land  \
# 0   Central Spain, Eastern Spain      53287,6           47466,8
# 1   Central Spain, Eastern Spain      53287,6           47466,8
# 2   Central Spain, Eastern Spain      53287,6           47466,8
# 3            North-Eastern Italy      13351,4            9583,8
# 4            North-Eastern Italy      13351,4            9583,8
# ..                           ...          ...               ...
# 63                      Slovenia        834,6             604,7
# 64                      Slovenia        834,6             604,7
# 65                      Slovenia        834,6             604,7
# 66           North-Eastern Italy      17898,7           11118,7
# 67                        Latvia       7220,5            6631,3
#
#    natural_ecosystems road_infrastructure railway_infrastructure  \
# 0               967,3              1523,4                   99,4
# 1               967,3              1523,4                   99,4
# 2               967,3              1523,4                   99,4
# 3              1539,9                19,3                    0,6
# 4              1539,9                19,3                    0,6
# ..                ...                 ...                    ...
# 63              134,1                16,6                    0,6
# 64              134,1                16,6                    0,6
# 65              134,1                16,6                    0,6
# 66               53,8                31,1                    0,9
# 67              427,1                29,7                      1
#
#    pipelines_and_communication_infrastructure residential_buildings_hectares  \
# 0                                       277,1                          656,7
# 1                                       277,1                          656,7
# 2                                       277,1                          656,7
# 3                                        34,3                            6,4
# 4                                        34,3                            6,4
# ..                                        ...                            ...
# 63                                        4,5                            1,6
# 64                                        4,5                            1,6
# 65                                        4,5                            1,6
# 66                                       55,5                           10,3
# 67                                       43,6                            2,7
#
#    population_affected
# 0               190090
# 1               190090
# 2               190090
# 3                  670
# 4                  670
# ..                 ...
# 63                1280
# 64                1280
# 65                1280
# 66                9250
# 67                 450
#
# [68 rows x 33 columns]

# %%
df_copernicus_nuts3.to_excel("final_df_copernicus_nuts3.xlsx", index=False, float_format="%.2f")

# %% [markdown]
# ## fix the columns create the ones you need

# %%
df_copernicus = pd.read_excel("final_df_copernicus_nuts3.xlsx")
df_copernicus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   activation_code                             68 non-null     object
#  1   event_name_x                                68 non-null     object
#  2   reason_x                                    68 non-null     object
#  3   activator_x                                 68 non-null     object
#  4   eventTime_x                                 68 non-null     object
#  5   activationTime_x                            68 non-null     object
#  6   countries_x                                 68 non-null     object
#  7   nuts3_name_2024                             68 non-null     object
#  8   nuts3_name_2024_en                          61 non-null     object
#  9   nuts3_code_2024                             61 non-null     object
#  10  nuts3_2024_urban_rural_typology             61 non-null     object
#  11  nuts3_2024_coastal_regions                  61 non-null     object
#  12  nuts2_name_2024_en                          65 non-null     object
#  13  nuts2_code_2024                             65 non-null     object
#  14  nuts1_name_2024_en                          68 non-null     object
#  15  nuts1_code_2024                             68 non-null     object
#  16  event_name_y                                68 non-null     object
#  17  reason_y                                    68 non-null     object
#  18  activator_y                                 68 non-null     object
#  19  eventTime_y                                 68 non-null     datetime64[ns]
#  20  activationTime_y                            68 non-null     datetime64[ns]
#  21  countries_y                                 68 non-null     object
#  22  nuts3_regions                               64 non-null     object
#  23  nuts2_regions                               66 non-null     object
#  24  nuts1_regions                               68 non-null     object
#  25  event_extent                                68 non-null     object
#  26  agricultural_land                           68 non-null     object
#  27  natural_ecosystems                          68 non-null     object
#  28  road_infrastructure                         68 non-null     object
#  29  railway_infrastructure                      61 non-null     object
#  30  pipelines_and_communication_infrastructure  60 non-null     object
#  31  residential_buildings_hectares              55 non-null     object
#  32  population_affected                         68 non-null     int64
# dtypes: datetime64[ns](2), int64(1), object(30)
# memory usage: 17.7+ KB

# %%
df_copernicus.rename(columns={
    "activation_code": "id",
    "event_name_y": "flood_name",
    "reason_x": "flood_info",
    "eventTime_x": "start_date",
    "countries_x": "country",
    "population_affected": "people_affected",
    "nuts3_name_2024_en": "nuts3_region",
    "nuts3_code_2024": "nuts3_code",
    "nuts3_2024_urban_rural_typology": "nuts3_region_urban_rural_typology",
    "nuts3_2024_coastal_regions": "nuts3_coastal_regions",
    "nuts2_name_2024_en" : "nuts2_region",
    "nuts2_code_2024": "nuts2_code",
    "nuts1_name_2024_en": "nuts1_region",
    "nuts1_code_2024": "nuts1_code",
}, inplace=True)

# %% [markdown]
# ### now keep all the columns you renamed

# %%
columns_to_keep = [
    "id",
    "flood_name",
    "flood_info",
    "start_date",
    "country",
    "people_affected",
    "nuts3_region",
    "nuts3_code",
    "nuts3_region_urban_rural_typology",
    "nuts3_coastal_regions",
    "nuts2_region",
    "nuts2_code",
    "nuts1_region",
    "nuts1_code"
]

# %%
df_copernicus = df_copernicus[columns_to_keep]

# %%
df_copernicus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 68 non-null     object
#  1   flood_name                         68 non-null     object
#  2   flood_info                         68 non-null     object
#  3   start_date                         68 non-null     object
#  4   country                            68 non-null     object
#  5   people_affected                    68 non-null     int64
#  6   nuts3_region                       61 non-null     object
#  7   nuts3_code                         61 non-null     object
#  8   nuts3_region_urban_rural_typology  61 non-null     object
#  9   nuts3_coastal_regions              61 non-null     object
#  10  nuts2_region                       65 non-null     object
#  11  nuts2_code                         65 non-null     object
#  12  nuts1_region                       68 non-null     object
#  13  nuts1_code                         68 non-null     object
# dtypes: int64(1), object(13)
# memory usage: 7.6+ KB

# %% [markdown]
# ### create columns
# create the year, data_exists, columns
#
# take fatalities, sources, notes, reportLink columns from excel "deaths_and_storm_names_all_aois_details_summaries_activations.xlsx"
#
# "end_date", "flood_type", "cause" will be empty in copernicus, no official data for them

# %% [markdown]
# #### year

# %%
df_copernicus["start_date"] = pd.to_datetime(df_copernicus["start_date"], errors="coerce")
df_copernicus["year"] = df_copernicus["start_date"].dt.year

# %% [markdown]
# #### data_exists

# %%
df_copernicus['data_exists'] = df_copernicus.apply(lambda x: 'copernicus', axis=1)

# %% [markdown]
# #### create the 3 empty columns

# %%
df_copernicus = df_copernicus.assign(end_date=None, flood_type=None, cause=None)

# %% [markdown]
# #### fatalities, sources, notes, reportLink columns from excel "deaths_and_storm_names_all_aois_details_summaries_activations.xlsx"

# %%
df_fatalities_sources_notes = pd.read_excel("deaths_and_storm_names_all_aois_details_summaries_activations.xlsx")

# %%
df_fatalities_sources_notes_unique = df_fatalities_sources_notes.drop_duplicates(subset=['activation_code'])

# %%
df_copernicus = pd.merge(df_copernicus, df_fatalities_sources_notes_unique, 
                         left_on='id', right_on='activation_code', how='left')

# %%
df_copernicus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 68 non-null     object
#  1   flood_name                         68 non-null     object
#  2   flood_info                         68 non-null     object
#  3   start_date                         68 non-null     datetime64[ns]
#  4   country                            68 non-null     object
#  5   people_affected                    68 non-null     int64
#  6   nuts3_region                       61 non-null     object
#  7   nuts3_code                         61 non-null     object
#  8   nuts3_region_urban_rural_typology  61 non-null     object
#  9   nuts3_coastal_regions              61 non-null     object
#  10  nuts2_region                       65 non-null     object
#  11  nuts2_code                         65 non-null     object
#  12  nuts1_region                       68 non-null     object
#  13  nuts1_code                         68 non-null     object
#  14  year                               68 non-null     int32
#  15  data_exists                        68 non-null     object
#  16  end_date                           0 non-null      object
#  17  flood_type                         0 non-null      object
#  18  cause                              0 non-null      object
#  19  activation_code                    68 non-null     object
#  20  event_name                         68 non-null     object
#  21  reason                             68 non-null     object
#  22  activator                          68 non-null     object
#  23  eventTime                          68 non-null     object
#  24  activationTime                     68 non-null     object
#  25  countries                          68 non-null     object
#  26  aoiName                            68 non-null     object
#  27  aoiNumber                          63 non-null     float64
#  28  type                               63 non-null     object
#  29  monitoring                         63 non-null     float64
#  30  deliveryTime                       63 non-null     object
#  31  category_unit                      68 non-null     object
#  32  unit_measurement                   68 non-null     object
#  33  subcategory_unit                   68 non-null     object
#  34  normalized_category_v1             63 non-null     object
#  35  normalized_category_v2             68 non-null     object
#  36  affected                           68 non-null     float64
#  37  for_checking_events                0 non-null      object
#  38  reportLink                         66 non-null     object
#  39  gdacsId                            33 non-null     object
#  40  fatalities                         36 non-null     float64
#  41  sources                            43 non-null     object
#  42  info_bulletin                      21 non-null     object
#  43  storm_name                         24 non-null     object
#  44  notes                              3 non-null      object
# dtypes: datetime64[ns](1), float64(4), int32(1), int64(1), object(38)
# memory usage: 23.8+ KB

# %% [markdown]
# #### drop the other columns

# %%
df_copernicus.drop(columns=[
    "activation_code", "event_name", "reason", "activator", "eventTime", "activationTime", "countries",
    "gdacsId", "info_bulletin", "storm_name", "aoiName", "aoiNumber", "type", "monitoring", "deliveryTime",
    "category_unit", "unit_measurement", "subcategory_unit", "normalized_category_v1", "normalized_category_v2",
    "affected", "for_checking_events"
], inplace=True, errors="ignore")

# %%
df_copernicus
# Out:
#          id                                         flood_name  \
# 0   EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 1   EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 2   EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 3   EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# 4   EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# ..      ...                                                ...
# 63  EMSR680  Flood in Eastern and Western Slovenia, on 4 Au...
# 64  EMSR680  Flood in Eastern and Western Slovenia, on 4 Au...
# 65  EMSR680  Flood in Eastern and Western Slovenia, on 4 Au...
# 66  EMSR664  Flood in Emilia-Romagna region, Italy on 16 Ma...
# 67  EMSR657  Flood in Daugava River valley, Latvia on 30 Ma...
#
#                                            flood_info          start_date  \
# 0   On 29 October 2024 at 14:30 UTC, an extraordin... 2024-10-29 14:30:00
# 1   On 29 October 2024 at 14:30 UTC, an extraordin... 2024-10-29 14:30:00
# 2   On 29 October 2024 at 14:30 UTC, an extraordin... 2024-10-29 14:30:00
# 3   Italy has been hit in recent days by a severe ... 2024-10-20 12:00:00
# 4   Italy has been hit in recent days by a severe ... 2024-10-20 12:00:00
# ..                                                ...                 ...
# 63  The Slovenian Environment Agency (ARSO) has is... 2023-08-04 09:00:00
# 64  The Slovenian Environment Agency (ARSO) has is... 2023-08-04 09:00:00
# 65  The Slovenian Environment Agency (ARSO) has is... 2023-08-04 09:00:00
# 66  A new wave of severe weather has again hit sou... 2023-05-16 11:00:00
# 67  As of 30 March 2023 a flood due to melted snow... 2023-03-30 00:00:00
#
#      country  people_affected            nuts3_region nuts3_code  \
# 0      Spain           190090      Valencia province       ES523
# 1      Spain           190090       Albacete province      ES421
# 2      Spain           190090      Castellón province      ES522
# 3      Italy              670  Reggio Emilia province      ITH53
# 4      Italy              670         Modena province      ITH54
# ..       ...              ...                     ...        ...
# 63  Slovenia             1280          Savinja region      SI034
# 64  Slovenia             1280          Pomurje region      SI031
# 65  Slovenia             1280   Upper Carniola region      SI042
# 66     Italy             9250   Forlì-Cesena province      ITH58
# 67    Latvia              450                     NaN        NaN
#
#    nuts3_region_urban_rural_typology nuts3_coastal_regions  ... nuts1_code  \
# 0                predominantly urban               coastal  ...        ES5
# 1                       intermediate           non-coastal  ...        ES4
# 2                       intermediate               coastal  ...        ES5
# 3                       intermediate           non-coastal  ...        ITH
# 4                       intermediate           non-coastal  ...        ITH
# ..                               ...                   ...  ...        ...
# 63               predominantly rural           non-coastal  ...        SI0
# 64               predominantly rural           non-coastal  ...        SI0
# 65                      intermediate           non-coastal  ...        SI0
# 66                      intermediate               coastal  ...        ITH
# 67                               NaN                   NaN  ...        LV0
#
#     year data_exists end_date  flood_type cause  \
# 0   2024  copernicus     None        None  None
# 1   2024  copernicus     None        None  None
# 2   2024  copernicus     None        None  None
# 3   2024  copernicus     None        None  None
# 4   2024  copernicus     None        None  None
# ..   ...         ...      ...         ...   ...
# 63  2023  copernicus     None        None  None
# 64  2023  copernicus     None        None  None
# 65  2023  copernicus     None        None  None
# 66  2023  copernicus     None        None  None
# 67  2023  copernicus     None        None  None
#
#                                            reportLink fatalities  \
# 0   https://storymaps.arcgis.com/stories/9ff57e932...      285.0
# 1   https://storymaps.arcgis.com/stories/9ff57e932...      285.0
# 2   https://storymaps.arcgis.com/stories/9ff57e932...      285.0
# 3   https://storymaps.arcgis.com/stories/b95e2210e...        1.0
# 4   https://storymaps.arcgis.com/stories/b95e2210e...        1.0
# ..                                                ...        ...
# 63  https://storymaps.arcgis.com/stories/cc84a70d5...        NaN
# 64  https://storymaps.arcgis.com/stories/cc84a70d5...        NaN
# 65  https://storymaps.arcgis.com/stories/cc84a70d5...        NaN
# 66                                                NaN       14.0
# 67                                                NaN        0.0
#
#                                 sources notes
# 0                             FL1102983   NaN
# 1                             FL1102983   NaN
# 2                             FL1102983   NaN
# 3                             FL1102961   NaN
# 4                             FL1102961   NaN
# ..                                  ...   ...
# 63                                  NaN   NaN
# 64                                  NaN   NaN
# 65                                  NaN   NaN
# 66  copernicus information bulletin 167   NaN
# 67                            FL1101921   NaN
#
# [68 rows x 23 columns]

# %% [markdown]
# ##### fix sources a bit (we also want copernicus in there and to specify that the code name is GDACS when there is one)

# %%
df_copernicus["sources"] = df_copernicus["sources"].apply(lambda x: f"GDACS ID {x}" if isinstance(x, str) and x.startswith("FL") else x)

# %%
df_copernicus["sources"].value_counts()
# Out:
# sources
# copernicus information bulletin 173                                                                      21
# GDACS ID FL1102602                                                                                        7
# GDACS ID FL1102961                                                                                        5
# GDACS ID FL1102983                                                                                        3
# https://www.news247.gr/ellada/plimmires-sti-thessalia-stous-17-afxithikan-oi-nekroi-enas-agnooumenos/     3
# https://www.bbc.com/news/world-europe-66715731                                                            2
# copernicus information bulletin 167                                                                       1
# GDACS ID FL1101921                                                                                        1
# Name: count, dtype: int64

# %%
df_copernicus["sources"] = df_copernicus["sources"].apply(lambda x: f"Copernicus, {x}" if pd.notna(x) and str(x).strip() else "Copernicus")

# %%
df_copernicus["sources"].value_counts()
# Out:
# sources
# Copernicus                                                                                                           25
# Copernicus, copernicus information bulletin 173                                                                      21
# Copernicus, GDACS ID FL1102602                                                                                        7
# Copernicus, GDACS ID FL1102961                                                                                        5
# Copernicus, GDACS ID FL1102983                                                                                        3
# Copernicus, https://www.news247.gr/ellada/plimmires-sti-thessalia-stous-17-afxithikan-oi-nekroi-enas-agnooumenos/     3
# Copernicus, https://www.bbc.com/news/world-europe-66715731                                                            2
# Copernicus, copernicus information bulletin 167                                                                       1
# Copernicus, GDACS ID FL1101921                                                                                        1
# Name: count, dtype: int64

# %% [markdown]
# #### finally reorder columns

# %%
df_copernicus = df_copernicus[[
    "id", "flood_name", "flood_info", "year", "country", "start_date", "end_date", "fatalities", "people_affected",
    "nuts3_region", "nuts3_code", "nuts3_region_urban_rural_typology", 
    "nuts3_coastal_regions", "nuts2_region", "nuts2_code", "nuts1_region", "nuts1_code", "cause", "flood_type", 
    "data_exists", "sources", "notes", "reportLink"
]]

# %%
df_copernicus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 68 non-null     object
#  1   flood_name                         68 non-null     object
#  2   flood_info                         68 non-null     object
#  3   year                               68 non-null     int32
#  4   country                            68 non-null     object
#  5   start_date                         68 non-null     datetime64[ns]
#  6   end_date                           0 non-null      object
#  7   fatalities                         36 non-null     float64
#  8   people_affected                    68 non-null     int64
#  9   nuts3_region                       61 non-null     object
#  10  nuts3_code                         61 non-null     object
#  11  nuts3_region_urban_rural_typology  61 non-null     object
#  12  nuts3_coastal_regions              61 non-null     object
#  13  nuts2_region                       65 non-null     object
#  14  nuts2_code                         65 non-null     object
#  15  nuts1_region                       68 non-null     object
#  16  nuts1_code                         68 non-null     object
#  17  cause                              0 non-null      object
#  18  flood_type                         0 non-null      object
#  19  data_exists                        68 non-null     object
#  20  sources                            68 non-null     object
#  21  notes                              3 non-null      object
#  22  reportLink                         66 non-null     object
# dtypes: datetime64[ns](1), float64(1), int32(1), int64(1), object(19)
# memory usage: 12.1+ KB

# %%
df_copernicus.to_excel("df_copernicus_final_for_merge_decade.xlsx", index=False)

# %% [markdown]
# # Now let's do the public em-dat dataset -> final_public_emdat_2022_2021.xlsx

# %%
df_emdat = pd.read_excel("final_public_emdat_2022_2021.xlsx")
df_emdat
# Out:
#                 id  flood_name  \
# 0    2022-0825-BIH         NaN
# 1    2022-0775-ITA         NaN
# 2    2022-0609-ITA         NaN
# 3    2022-0609-ITA         NaN
# 4    2022-0585-BGR         NaN
# ..             ...         ...
# 130  2021-0020-SRB         NaN
# 131  2021-0020-SRB         NaN
# 132  2021-0016-ESP         NaN
# 133  2021-0016-ESP         NaN
# 134  2021-0016-ESP         NaN
#
#                                             flood_info  year subregion_europe  \
# 0                                                  NaN  2022  Southern Europe
# 1    Following the mudflow event that affected Casa...  2022  Southern Europe
# 2     On 15 September 2022, an extremely intense we...  2022  Southern Europe
# 3     On 15 September 2022, an extremely intense we...  2022  Southern Europe
# 4    Torrential rain from 02 September 2022 caused ...  2022   Eastern Europe
# ..                                                 ...   ...              ...
# 130  In Serbia, the Ministry of Interior reported a...  2021   Eastern Europe
# 131  In Serbia, the Ministry of Interior reported a...  2021   Eastern Europe
# 132                                                NaN  2021  Southern Europe
# 133                                                NaN  2021  Southern Europe
# 134                                                NaN  2021  Southern Europe
#
#       country start_date   end_date            type            location  ...  \
# 0     Croatia 2022-12-11 2022-12-11             NaN   Zadarska županija  ...
# 1       Italy 2022-11-26 2022-11-26           flood  Casamicciola Terme  ...
# 2       Italy 2022-09-15 2022-09-16  riverine flood              Ancona  ...
# 3       Italy 2022-09-15 2022-09-16  riverine flood     Pesaro e Urbino  ...
# 4    Bulgaria 2022-09-02 2022-09-02  riverine flood    Plovdiv province  ...
# ..        ...        ...        ...             ...                 ...  ...
# 130    Serbia 2021-01-11 2021-01-12             NaN              Bojnik  ...
# 131    Serbia 2021-01-11 2021-01-12             NaN            Leskovac  ...
# 132     Spain 2021-01-08 2021-01-12             NaN              Madrid  ...
# 133     Spain 2021-01-08 2021-01-12             NaN              Malaga  ...
# 134     Spain 2021-01-08 2021-01-12             NaN            Zaragoza  ...
#
#     nuts3_2024_urban_rural_typology nuts3_2024_coastal_regions  \
# 0                               NaN                        NaN
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# ..                              ...                        ...
# 130                             NaN                        NaN
# 131                             NaN                        NaN
# 132                             NaN                        NaN
# 133                             NaN                        NaN
# 134                             NaN                        NaN
#
#                  nuts2_name_2024  nuts2_code_2024 fatalities  \
# 0                            NaN              NaN        NaN
# 1                            NaN              NaN       12.0
# 2                            NaN              NaN       12.0
# 3                            NaN              NaN       12.0
# 4                            NaN              NaN        NaN
# ..                           ...              ...        ...
# 130  Southern and Eastern Serbia              RS2        NaN
# 131  Southern and Eastern Serbia              RS2        NaN
# 132                          NaN              NaN        5.0
# 133                          NaN              NaN        5.0
# 134                          NaN              NaN        5.0
#
#     people_affected_per_event                  cause  \
# 0                         5.0                    NaN
# 1                       230.0            heavy rains
# 2                        33.0            heavy rains
# 3                        33.0            heavy rains
# 4                     10937.0            heavy rains
# ..                        ...                    ...
# 130                      22.0            heavy rains
# 131                      22.0            heavy rains
# 132                       NaN  blizzard/winter storm
# 133                       NaN  blizzard/winter storm
# 134                       NaN  blizzard/winter storm
#
#                               data_exists  \
# 0                       em-dat, floodlist
# 1               em-dat, gdacs, copernicus
# 2                       copernicus,em-dat
# 3                       copernicus,em-dat
# 4    copernicus, floodlist, em-dat, glide
# ..                                    ...
# 130                     em-dat, floodlist
# 131                     em-dat, floodlist
# 132                    copernicus, em-dat
# 133                    copernicus, em-dat
# 134                    copernicus, em-dat
#
#                                                sources  \
# 0    https://floodlist.com/europe/bosnia-croatia-fl...
# 1                                                  NaN
# 2    https://emergency.copernicus.eu/mapping/list-o...
# 3    https://emergency.copernicus.eu/mapping/list-o...
# 4    https://floodlist.com/europe/bulgaria-floods-p...
# ..                                                 ...
# 130  https://floodlist.com/europe/serbia-bulgaria-a...
# 131  https://floodlist.com/europe/serbia-bulgaria-a...
# 132  https://www.theguardian.com/world/2021/jan/10/...
# 133  https://www.theguardian.com/world/2021/jan/10/...
# 134  https://www.theguardian.com/world/2021/jan/10/...
#
#                                         notes
# 0                                         NaN
# 1           source for deaths copernicus essd
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 130                                       NaN
# 131  source of people affected from floodlist
# 132                                       NaN
# 133                                       NaN
# 134                                       NaN
#
# [135 rows x 22 columns]

# %% [markdown]
# ### rename columns

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               135 non-null    object
#  1   flood_name                       0 non-null      float64
#  2   flood_info                       78 non-null     object
#  3   year                             135 non-null    int64
#  4   subregion_europe                 135 non-null    object
#  5   country                          135 non-null    object
#  6   start_date                       135 non-null    datetime64[ns]
#  7   end_date                         121 non-null    datetime64[ns]
#  8   type                             102 non-null    object
#  9   location                         135 non-null    object
#  10  nuts3_name_2024                  108 non-null    object
#  11  nuts3_code_2024                  108 non-null    object
#  12  nuts3_2024_urban_rural_typology  0 non-null      float64
#  13  nuts3_2024_coastal_regions       0 non-null      float64
#  14  nuts2_name_2024                  53 non-null     object
#  15  nuts2_code_2024                  29 non-null     object
#  16  fatalities                       80 non-null     float64
#  17  people_affected_per_event        74 non-null     float64
#  18  cause                            115 non-null    object
#  19  data_exists                      135 non-null    object
#  20  sources                          81 non-null     object
#  21  notes                            27 non-null     object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(14)
# memory usage: 23.3+ KB

# %%
df_emdat.rename(columns={
    "people_affected_per_event": "people_affected",
    "type": "flood_type",
    "nuts3_name_2024": "nuts3_region",
    "nuts3_code_2024": "nuts3_code",
    "nuts2_name_2024": "nuts2_region",
    "nuts2_code_2024": "nuts2_code"
}, inplace=True)

# %% [markdown]
# ### drop columns we won't need
#
# coastal and rural-urban columns are empty, you'll get them later from merging

# %%
df_emdat.drop(columns=['subregion_europe', 'nuts3_2024_urban_rural_typology', 'nuts3_2024_coastal_regions', 'location'], inplace=True)

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               135 non-null    object
#  1   flood_name       0 non-null      float64
#  2   flood_info       78 non-null     object
#  3   year             135 non-null    int64
#  4   country          135 non-null    object
#  5   start_date       135 non-null    datetime64[ns]
#  6   end_date         121 non-null    datetime64[ns]
#  7   flood_type       102 non-null    object
#  8   nuts3_region     108 non-null    object
#  9   nuts3_code       108 non-null    object
#  10  nuts2_region     53 non-null     object
#  11  nuts2_code       29 non-null     object
#  12  fatalities       80 non-null     float64
#  13  people_affected  74 non-null     float64
#  14  cause            115 non-null    object
#  15  data_exists      135 non-null    object
#  16  sources          81 non-null     object
#  17  notes            27 non-null     object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(12)
# memory usage: 19.1+ KB

# %% [markdown]
# ### get the coastal and rural-urban columns -> nuts3_regions_2024_typologies.xlsx
# ### along with the nuts1_region and nuts1_code columns by merging your df with the appropriate excel-> all_nuts_2024_sheet_from_NUTS2021-NUTS2024.xlsx

# %%
df_nuts3_typologies = pd.read_excel("nuts3_regions_2024_typologies.xlsx")
df_nuts3_typologies
# Out:
#      Country code NUTS-3 Code  \
# 0              BE       BE100
# 1              BE       BE211
# 2              BE       BE212
# 3              BE       BE213
# 4              BE       BE223
# ...           ...         ...
# 1160           SE       SE313
# 1161           SE       SE321
# 1162           SE       SE322
# 1163           SE       SE331
# 1164           SE       SE332
#
#                                            NUTS-3 label Urban-Rural typology  \
# 0     Arr. de Bruxelles-Capitale/Arr. van Brussel-Ho...  predominantly urban
# 1                                        Arr. Antwerpen  predominantly urban
# 2                                         Arr. Mechelen  predominantly urban
# 3                                         Arr. Turnhout         intermediate
# 4                                         Arr. Tongeren         intermediate
# ...                                                 ...                  ...
# 1160                                     Gävleborgs län         intermediate
# 1161                                Västernorrlands län         intermediate
# 1162                                      Jämtlands län  predominantly rural
# 1163                                  Västerbottens län         intermediate
# 1164                                    Norrbottens län         intermediate
#
#      Coastal regions  Metropolitan regions  Border regions  Island regions  \
# 0        non-coastal                   NaN             NaN             NaN
# 1            coastal                   NaN             NaN             NaN
# 2            coastal                   NaN             NaN             NaN
# 3        non-coastal                   NaN             NaN             NaN
# 4        non-coastal                   NaN             NaN             NaN
# ...              ...                   ...             ...             ...
# 1160         coastal                   NaN             NaN             NaN
# 1161         coastal                   NaN             NaN             NaN
# 1162     non-coastal                   NaN             NaN             NaN
# 1163         coastal                   NaN             NaN             NaN
# 1164         coastal                   NaN             NaN             NaN
#
#       Mountanious regions Capital regions
# 0                     NaN  Capital region
# 1                     NaN             NaN
# 2                     NaN             NaN
# 3                     NaN             NaN
# 4                     NaN             NaN
# ...                   ...             ...
# 1160                  NaN             NaN
# 1161                  NaN             NaN
# 1162                  NaN             NaN
# 1163                  NaN             NaN
# 1164                  NaN             NaN
#
# [1165 rows x 10 columns]

# %% [markdown]
# ### merge on NUTS-3 code

# %%
df_emdat = pd.merge(df_emdat, df_nuts3_typologies, left_on='nuts3_code', right_on='NUTS-3 Code', how='left')

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 28 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    135 non-null    object
#  1   flood_name            0 non-null      float64
#  2   flood_info            78 non-null     object
#  3   year                  135 non-null    int64
#  4   country               135 non-null    object
#  5   start_date            135 non-null    datetime64[ns]
#  6   end_date              121 non-null    datetime64[ns]
#  7   flood_type            102 non-null    object
#  8   nuts3_region          108 non-null    object
#  9   nuts3_code            108 non-null    object
#  10  nuts2_region          53 non-null     object
#  11  nuts2_code            29 non-null     object
#  12  fatalities            80 non-null     float64
#  13  people_affected       74 non-null     float64
#  14  cause                 115 non-null    object
#  15  data_exists           135 non-null    object
#  16  sources               81 non-null     object
#  17  notes                 27 non-null     object
#  18  Country code          101 non-null    object
#  19  NUTS-3 Code           101 non-null    object
#  20  NUTS-3 label          101 non-null    object
#  21  Urban-Rural typology  101 non-null    object
#  22  Coastal regions       101 non-null    object
#  23  Metropolitan regions  0 non-null      float64
#  24  Border regions        0 non-null      float64
#  25  Island regions        0 non-null      float64
#  26  Mountanious regions   0 non-null      float64
#  27  Capital regions       4 non-null      object
# dtypes: datetime64[ns](2), float64(7), int64(1), object(18)
# memory usage: 29.7+ KB

# %% [markdown]
# #### drop what you don't need (drop the extra nuts 3 code after you check if its correct)

# %%
df_emdat.drop(columns=['Country code', 'NUTS-3 label', 'Metropolitan regions', 'Border regions', 'Island regions', 'Mountanious regions', 'Capital regions'], inplace=True)

# %% [markdown]
# #### rename

# %%
df_emdat.rename(columns={
    "Urban-Rural typology": "nuts3_region_urban_rural_typology",
    "Coastal regions": "nuts3_coastal_regions"
}, inplace=True)

# %% [markdown]
# ### merge with all_nuts_2024_sheet_from_NUTS2021-NUTS2024.xlsx to have nuts1 name and code

# %%
df_nuts_regions = pd.read_excel("all_nuts_2024_sheet_from_NUTS2021-NUTS2024.xlsx")
df_nuts_regions
# Out:
#      Country code NUTS Code  \
# 0              BE       BE1
# 1              BE      BE10
# 2              BE     BE100
# 3              BE       BE2
# 4              BE      BE21
# ...           ...       ...
# 1577           SE     SE331
# 1578           SE     SE332
# 1579           SE       SEZ
# 1580           SE      SEZZ
# 1581           SE     SEZZZ
#
#                                              NUTS label  NUTS level  \
# 0     Région de Bruxelles-Capitale/Brussels Hoofdste...           1
# 1     Région de Bruxelles-Capitale/Brussels Hoofdste...           2
# 2     Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad           3
# 3                                         Vlaams Gewest           1
# 4                                       Prov. Antwerpen           2
# ...                                                 ...         ...
# 1577                                  Västerbottens län           3
# 1578                                    Norrbottens län           3
# 1579                                 Extra-Regio NUTS 1           1
# 1580                                 Extra-Regio NUTS 2           2
# 1581                                 Extra-Regio NUTS 3           3
#
#       Country order     #
# 0                 1     1
# 1                 1     2
# 2                 1     3
# 3                 1     4
# 4                 1     5
# ...             ...   ...
# 1577             27  1578
# 1578             27  1579
# 1579             27  1580
# 1580             27  1581
# 1581             27  1582
#
# [1582 rows x 6 columns]

# %%
df_nuts_regions.drop(columns=['NUTS level', 'Country order', '#', 'Country code'], inplace=True)

# %% [markdown]
# #### create the columns for nuts 2 and nuts 1 regions to merge with NUTS2021-NUTS2024 data

# %%
df_emdat['nuts2_code_new'] = df_emdat['nuts3_code'].apply(lambda x: x[:-1] if pd.notna(x) else None)

# %%
df_emdat["nuts2_code_new"] = df_emdat.apply(
    lambda x: x["nuts2_code"] if pd.isna(x["nuts2_code_new"]) and pd.isna(x["nuts3_region"]) and pd.notna(x["nuts2_code"]) else x["nuts2_code_new"], 
    axis=1
)

# %%
df_emdat = pd.merge(df_emdat, df_nuts_regions, left_on='nuts2_code_new', right_on='NUTS Code', how='left')

# %% [markdown]
# #### drop and rename

# %%
df_emdat.rename(columns={'NUTS label': 'nuts2_name_new'}, inplace=True)

# %%
df_emdat
# Out:
#                 id  flood_name  \
# 0    2022-0825-BIH         NaN
# 1    2022-0775-ITA         NaN
# 2    2022-0609-ITA         NaN
# 3    2022-0609-ITA         NaN
# 4    2022-0585-BGR         NaN
# ..             ...         ...
# 130  2021-0020-SRB         NaN
# 131  2021-0020-SRB         NaN
# 132  2021-0016-ESP         NaN
# 133  2021-0016-ESP         NaN
# 134  2021-0016-ESP         NaN
#
#                                             flood_info  year   country  \
# 0                                                  NaN  2022   Croatia
# 1    Following the mudflow event that affected Casa...  2022     Italy
# 2     On 15 September 2022, an extremely intense we...  2022     Italy
# 3     On 15 September 2022, an extremely intense we...  2022     Italy
# 4    Torrential rain from 02 September 2022 caused ...  2022  Bulgaria
# ..                                                 ...   ...       ...
# 130  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 131  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 132                                                NaN  2021     Spain
# 133                                                NaN  2021     Spain
# 134                                                NaN  2021     Spain
#
#     start_date   end_date      flood_type                     nuts3_region  \
# 0   2022-12-11 2022-12-11             NaN                     Zadar county
# 1   2022-11-26 2022-11-26           flood  Casamicciola Terme municipality
# 2   2022-09-15 2022-09-16  riverine flood                  Ancona province
# 3   2022-09-15 2022-09-16  riverine flood                  Pesaro province
# 4   2022-09-02 2022-09-02  riverine flood                 Plovdiv province
# ..         ...        ...             ...                              ...
# 130 2021-01-11 2021-01-12             NaN               Jablanica District
# 131 2021-01-11 2021-01-12             NaN               Jablanica District
# 132 2021-01-08 2021-01-12             NaN                           Madrid
# 133 2021-01-08 2021-01-12             NaN                  Málaga province
# 134 2021-01-08 2021-01-12             NaN                Zaragoza province
#
#     nuts3_code  ...                  cause  \
# 0        HR033  ...                    NaN
# 1        ITF33  ...            heavy rains
# 2        ITI32  ...            heavy rains
# 3        ITI31  ...            heavy rains
# 4        BG421  ...            heavy rains
# ..         ...  ...                    ...
# 130      RS223  ...            heavy rains
# 131      RS223  ...            heavy rains
# 132      ES300  ...  blizzard/winter storm
# 133      ES617  ...  blizzard/winter storm
# 134      ES243  ...  blizzard/winter storm
#
#                               data_exists  \
# 0                       em-dat, floodlist
# 1               em-dat, gdacs, copernicus
# 2                       copernicus,em-dat
# 3                       copernicus,em-dat
# 4    copernicus, floodlist, em-dat, glide
# ..                                    ...
# 130                     em-dat, floodlist
# 131                     em-dat, floodlist
# 132                    copernicus, em-dat
# 133                    copernicus, em-dat
# 134                    copernicus, em-dat
#
#                                                sources  \
# 0    https://floodlist.com/europe/bosnia-croatia-fl...
# 1                                                  NaN
# 2    https://emergency.copernicus.eu/mapping/list-o...
# 3    https://emergency.copernicus.eu/mapping/list-o...
# 4    https://floodlist.com/europe/bulgaria-floods-p...
# ..                                                 ...
# 130  https://floodlist.com/europe/serbia-bulgaria-a...
# 131  https://floodlist.com/europe/serbia-bulgaria-a...
# 132  https://www.theguardian.com/world/2021/jan/10/...
# 133  https://www.theguardian.com/world/2021/jan/10/...
# 134  https://www.theguardian.com/world/2021/jan/10/...
#
#                                         notes NUTS-3 Code  \
# 0                                         NaN       HR033
# 1           source for deaths copernicus essd       ITF33
# 2                                         NaN       ITI32
# 3                                         NaN       ITI31
# 4                                         NaN       BG421
# ..                                        ...         ...
# 130                                       NaN         NaN
# 131  source of people affected from floodlist         NaN
# 132                                       NaN       ES300
# 133                                       NaN       ES617
# 134                                       NaN       ES243
#
#     nuts3_region_urban_rural_typology nuts3_coastal_regions nuts2_code_new  \
# 0                 predominantly rural               coastal           HR03
# 1                 predominantly urban               coastal           ITF3
# 2                        intermediate               coastal           ITI3
# 3                        intermediate               coastal           ITI3
# 4                        intermediate           non-coastal           BG42
# ..                                ...                   ...            ...
# 130                               NaN                   NaN           RS22
# 131                               NaN                   NaN           RS22
# 132               predominantly urban           non-coastal           ES30
# 133               predominantly urban               coastal           ES61
# 134               predominantly urban           non-coastal           ES24
#
#     NUTS Code       nuts2_name_new
# 0        HR03   Jadranska Hrvatska
# 1        ITF3             Campania
# 2        ITI3               Marche
# 3        ITI3               Marche
# 4        BG42       Южен централен
# ..        ...                  ...
# 130       NaN                  NaN
# 131       NaN                  NaN
# 132      ES30  Comunidad de Madrid
# 133      ES61            Andalucía
# 134      ES24               Aragón
#
# [135 rows x 24 columns]

# %%
df_emdat.drop(columns=['NUTS-3 Code', 'NUTS Code'], inplace=True)

# %% [markdown]
# #### now do nuts1 regions

# %%
df_emdat['nuts1_code_new'] = df_emdat['nuts2_code_new'].apply(lambda x: x[:-1] if pd.notna(x) else None)

# %%
df_emdat = pd.merge(df_emdat, df_nuts_regions, left_on='nuts1_code_new', right_on='NUTS Code', how='left')

# %%
df_emdat
# Out:
#                 id  flood_name  \
# 0    2022-0825-BIH         NaN
# 1    2022-0775-ITA         NaN
# 2    2022-0609-ITA         NaN
# 3    2022-0609-ITA         NaN
# 4    2022-0585-BGR         NaN
# ..             ...         ...
# 130  2021-0020-SRB         NaN
# 131  2021-0020-SRB         NaN
# 132  2021-0016-ESP         NaN
# 133  2021-0016-ESP         NaN
# 134  2021-0016-ESP         NaN
#
#                                             flood_info  year   country  \
# 0                                                  NaN  2022   Croatia
# 1    Following the mudflow event that affected Casa...  2022     Italy
# 2     On 15 September 2022, an extremely intense we...  2022     Italy
# 3     On 15 September 2022, an extremely intense we...  2022     Italy
# 4    Torrential rain from 02 September 2022 caused ...  2022  Bulgaria
# ..                                                 ...   ...       ...
# 130  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 131  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 132                                                NaN  2021     Spain
# 133                                                NaN  2021     Spain
# 134                                                NaN  2021     Spain
#
#     start_date   end_date      flood_type                     nuts3_region  \
# 0   2022-12-11 2022-12-11             NaN                     Zadar county
# 1   2022-11-26 2022-11-26           flood  Casamicciola Terme municipality
# 2   2022-09-15 2022-09-16  riverine flood                  Ancona province
# 3   2022-09-15 2022-09-16  riverine flood                  Pesaro province
# 4   2022-09-02 2022-09-02  riverine flood                 Plovdiv province
# ..         ...        ...             ...                              ...
# 130 2021-01-11 2021-01-12             NaN               Jablanica District
# 131 2021-01-11 2021-01-12             NaN               Jablanica District
# 132 2021-01-08 2021-01-12             NaN                           Madrid
# 133 2021-01-08 2021-01-12             NaN                  Málaga province
# 134 2021-01-08 2021-01-12             NaN                Zaragoza province
#
#     nuts3_code  ...                           data_exists  \
# 0        HR033  ...                     em-dat, floodlist
# 1        ITF33  ...             em-dat, gdacs, copernicus
# 2        ITI32  ...                     copernicus,em-dat
# 3        ITI31  ...                     copernicus,em-dat
# 4        BG421  ...  copernicus, floodlist, em-dat, glide
# ..         ...  ...                                   ...
# 130      RS223  ...                     em-dat, floodlist
# 131      RS223  ...                     em-dat, floodlist
# 132      ES300  ...                    copernicus, em-dat
# 133      ES617  ...                    copernicus, em-dat
# 134      ES243  ...                    copernicus, em-dat
#
#                                                sources  \
# 0    https://floodlist.com/europe/bosnia-croatia-fl...
# 1                                                  NaN
# 2    https://emergency.copernicus.eu/mapping/list-o...
# 3    https://emergency.copernicus.eu/mapping/list-o...
# 4    https://floodlist.com/europe/bulgaria-floods-p...
# ..                                                 ...
# 130  https://floodlist.com/europe/serbia-bulgaria-a...
# 131  https://floodlist.com/europe/serbia-bulgaria-a...
# 132  https://www.theguardian.com/world/2021/jan/10/...
# 133  https://www.theguardian.com/world/2021/jan/10/...
# 134  https://www.theguardian.com/world/2021/jan/10/...
#
#                                         notes  \
# 0                                         NaN
# 1           source for deaths copernicus essd
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 130                                       NaN
# 131  source of people affected from floodlist
# 132                                       NaN
# 133                                       NaN
# 134                                       NaN
#
#      nuts3_region_urban_rural_typology nuts3_coastal_regions nuts2_code_new  \
# 0                  predominantly rural               coastal           HR03
# 1                  predominantly urban               coastal           ITF3
# 2                         intermediate               coastal           ITI3
# 3                         intermediate               coastal           ITI3
# 4                         intermediate           non-coastal           BG42
# ..                                 ...                   ...            ...
# 130                                NaN                   NaN           RS22
# 131                                NaN                   NaN           RS22
# 132                predominantly urban           non-coastal           ES30
# 133                predominantly urban               coastal           ES61
# 134                predominantly urban           non-coastal           ES24
#
#           nuts2_name_new nuts1_code_new NUTS Code  \
# 0     Jadranska Hrvatska            HR0       HR0
# 1               Campania            ITF       ITF
# 2                 Marche            ITI       ITI
# 3                 Marche            ITI       ITI
# 4         Южен централен            BG4       BG4
# ..                   ...            ...       ...
# 130                  NaN            RS2       NaN
# 131                  NaN            RS2       NaN
# 132  Comunidad de Madrid            ES3       ES3
# 133            Andalucía            ES6       ES6
# 134               Aragón            ES2       ES2
#
#                                NUTS label
# 0                                Hrvatska
# 1                                     Sud
# 2                             Centro (IT)
# 3                             Centro (IT)
# 4    Югозападна и Южна централна България
# ..                                    ...
# 130                                   NaN
# 131                                   NaN
# 132                   Comunidad de Madrid
# 133                                   Sur
# 134                               Noreste
#
# [135 rows x 25 columns]

# %%
df_emdat.rename(columns={'NUTS label': 'nuts1_name_new'}, inplace=True)

# %%
df_emdat.drop(columns=['NUTS Code'], inplace=True)

# %% [markdown]
# #### check what's wrong with some missing values from nuts3 (they might be old codes and not 2024 codes)

# %%
df_emdat.to_excel("df_emdat_test_check.xlsx", index=False)

# %% [markdown]
# #### missing values in nuts3 besides not having a nuts3 region, is due to serbia which does not have typologies for its nuts3 regions in the eu commission excel

# %% [markdown]
# ### drop, rename, fix sources create reportLink here as well

# %%
df_emdat.drop(columns=['nuts2_region', 'nuts2_code'], inplace=True)

# %%
df_emdat.rename(columns={
    'nuts2_code_new': 'nuts2_code',
    'nuts2_name_new': 'nuts2_region',
    'nuts1_code_new': 'nuts1_code',
    'nuts1_name_new': 'nuts1_region'
}, inplace=True)

# %%
df_emdat
# Out:
#                 id  flood_name  \
# 0    2022-0825-BIH         NaN
# 1    2022-0775-ITA         NaN
# 2    2022-0609-ITA         NaN
# 3    2022-0609-ITA         NaN
# 4    2022-0585-BGR         NaN
# ..             ...         ...
# 130  2021-0020-SRB         NaN
# 131  2021-0020-SRB         NaN
# 132  2021-0016-ESP         NaN
# 133  2021-0016-ESP         NaN
# 134  2021-0016-ESP         NaN
#
#                                             flood_info  year   country  \
# 0                                                  NaN  2022   Croatia
# 1    Following the mudflow event that affected Casa...  2022     Italy
# 2     On 15 September 2022, an extremely intense we...  2022     Italy
# 3     On 15 September 2022, an extremely intense we...  2022     Italy
# 4    Torrential rain from 02 September 2022 caused ...  2022  Bulgaria
# ..                                                 ...   ...       ...
# 130  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 131  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 132                                                NaN  2021     Spain
# 133                                                NaN  2021     Spain
# 134                                                NaN  2021     Spain
#
#     start_date   end_date      flood_type                     nuts3_region  \
# 0   2022-12-11 2022-12-11             NaN                     Zadar county
# 1   2022-11-26 2022-11-26           flood  Casamicciola Terme municipality
# 2   2022-09-15 2022-09-16  riverine flood                  Ancona province
# 3   2022-09-15 2022-09-16  riverine flood                  Pesaro province
# 4   2022-09-02 2022-09-02  riverine flood                 Plovdiv province
# ..         ...        ...             ...                              ...
# 130 2021-01-11 2021-01-12             NaN               Jablanica District
# 131 2021-01-11 2021-01-12             NaN               Jablanica District
# 132 2021-01-08 2021-01-12             NaN                           Madrid
# 133 2021-01-08 2021-01-12             NaN                  Málaga province
# 134 2021-01-08 2021-01-12             NaN                Zaragoza province
#
#     nuts3_code  ...                  cause  \
# 0        HR033  ...                    NaN
# 1        ITF33  ...            heavy rains
# 2        ITI32  ...            heavy rains
# 3        ITI31  ...            heavy rains
# 4        BG421  ...            heavy rains
# ..         ...  ...                    ...
# 130      RS223  ...            heavy rains
# 131      RS223  ...            heavy rains
# 132      ES300  ...  blizzard/winter storm
# 133      ES617  ...  blizzard/winter storm
# 134      ES243  ...  blizzard/winter storm
#
#                               data_exists  \
# 0                       em-dat, floodlist
# 1               em-dat, gdacs, copernicus
# 2                       copernicus,em-dat
# 3                       copernicus,em-dat
# 4    copernicus, floodlist, em-dat, glide
# ..                                    ...
# 130                     em-dat, floodlist
# 131                     em-dat, floodlist
# 132                    copernicus, em-dat
# 133                    copernicus, em-dat
# 134                    copernicus, em-dat
#
#                                                sources  \
# 0    https://floodlist.com/europe/bosnia-croatia-fl...
# 1                                                  NaN
# 2    https://emergency.copernicus.eu/mapping/list-o...
# 3    https://emergency.copernicus.eu/mapping/list-o...
# 4    https://floodlist.com/europe/bulgaria-floods-p...
# ..                                                 ...
# 130  https://floodlist.com/europe/serbia-bulgaria-a...
# 131  https://floodlist.com/europe/serbia-bulgaria-a...
# 132  https://www.theguardian.com/world/2021/jan/10/...
# 133  https://www.theguardian.com/world/2021/jan/10/...
# 134  https://www.theguardian.com/world/2021/jan/10/...
#
#                                         notes  \
# 0                                         NaN
# 1           source for deaths copernicus essd
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 130                                       NaN
# 131  source of people affected from floodlist
# 132                                       NaN
# 133                                       NaN
# 134                                       NaN
#
#     nuts3_region_urban_rural_typology nuts3_coastal_regions nuts2_code  \
# 0                 predominantly rural               coastal       HR03
# 1                 predominantly urban               coastal       ITF3
# 2                        intermediate               coastal       ITI3
# 3                        intermediate               coastal       ITI3
# 4                        intermediate           non-coastal       BG42
# ..                                ...                   ...        ...
# 130                               NaN                   NaN       RS22
# 131                               NaN                   NaN       RS22
# 132               predominantly urban           non-coastal       ES30
# 133               predominantly urban               coastal       ES61
# 134               predominantly urban           non-coastal       ES24
#
#             nuts2_region nuts1_code                          nuts1_region
# 0     Jadranska Hrvatska        HR0                              Hrvatska
# 1               Campania        ITF                                   Sud
# 2                 Marche        ITI                           Centro (IT)
# 3                 Marche        ITI                           Centro (IT)
# 4         Южен централен        BG4  Югозападна и Южна централна България
# ..                   ...        ...                                   ...
# 130                  NaN        RS2                                   NaN
# 131                  NaN        RS2                                   NaN
# 132  Comunidad de Madrid        ES3                   Comunidad de Madrid
# 133            Andalucía        ES6                                   Sur
# 134               Aragón        ES2                               Noreste
#
# [135 rows x 22 columns]

# %%
df_emdat.rename(columns={'sources': 'reportLink'}, inplace=True)

# %% [markdown]
# #### create the sources column

# %%
df_emdat["sources"] = df_emdat.apply(
    lambda x: f"{x['data_exists']}, {re.search(r'https://(.*?)/', str(x['reportLink'])).group(1)}"
    if pd.notna(x["reportLink"]) and "https://" in str(x["reportLink"])
    else x["data_exists"], 
    axis=1
)

# %%
df_emdat["sources"].value_counts()
# Out:
# sources
# em-dat, floodlist, floodlist.com                       56
# em-dat                                                 49
# copernicus, emergency.copernicus.eu                     5
# copernicus, english.elpais.com                          4
# em-dat, floodlist                                       4
# copernicis, emergency.copernicus.eu                     4
# copernicus, em-dat, floodlist, floodlist.com            3
# copernicus, em-dat, www.theguardian.com                 3
# copernicus,em-dat, emergency.copernicus.eu              2
# em-dat, gdacs, copernicus                               1
# copernicus, floodlist, em-dat, glide, floodlist.com     1
# em-dat, www.euronews.com                                1
# copernicus, www.bbc.com                                 1
# em-dat, copernicus, emergency.copernicus.eu             1
# Name: count, dtype: int64

# %% [markdown]
# #### finally reorder your columns the same way as copernicus

# %%
df_emdat = df_emdat[[
    "id", "flood_name", "flood_info", "year", "country", "start_date", "end_date", "fatalities", "people_affected",
    "nuts3_region", "nuts3_code", "nuts3_region_urban_rural_typology", 
    "nuts3_coastal_regions", "nuts2_region", "nuts2_code", "nuts1_region", "nuts1_code", "cause", "flood_type", 
    "data_exists", "sources", "notes", "reportLink"
]]

# %%
df_emdat.to_excel("df_emdat_final_for_merge_decade.xlsx", index=False)

# %% [markdown]
# #### notes: lapland was there four times when there was only one region (in the original em dat file I had created it had 4 different locations correspong to only one unique nuts3 and not 4 different ones, mistake acquired during the drop down option of excel that changed the code of the nuts3 region)

# %% [markdown]
# ### fix the english version of the columns nuts2 and nuts 1 by merging with the df_copernicus data codes that's already english, if they are regions that do not exist in the copernicus data do it by hand

# %%
df_copernicus_nuts2 = df_copernicus[["nuts2_region", "nuts2_code"]].drop_duplicates().copy()

# %%
df_emdat = pd.merge(df_emdat, df_copernicus_nuts2, on='nuts2_code', how='left')

# %%
df_emdat
# Out:
#                 id  flood_name  \
# 0    2022-0825-BIH         NaN
# 1    2022-0775-ITA         NaN
# 2    2022-0609-ITA         NaN
# 3    2022-0609-ITA         NaN
# 4    2022-0585-BGR         NaN
# ..             ...         ...
# 130  2021-0020-SRB         NaN
# 131  2021-0020-SRB         NaN
# 132  2021-0016-ESP         NaN
# 133  2021-0016-ESP         NaN
# 134  2021-0016-ESP         NaN
#
#                                             flood_info  year   country  \
# 0                                                  NaN  2022   Croatia
# 1    Following the mudflow event that affected Casa...  2022     Italy
# 2     On 15 September 2022, an extremely intense we...  2022     Italy
# 3     On 15 September 2022, an extremely intense we...  2022     Italy
# 4    Torrential rain from 02 September 2022 caused ...  2022  Bulgaria
# ..                                                 ...   ...       ...
# 130  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 131  In Serbia, the Ministry of Interior reported a...  2021    Serbia
# 132                                                NaN  2021     Spain
# 133                                                NaN  2021     Spain
# 134                                                NaN  2021     Spain
#
#     start_date   end_date  fatalities  people_affected  \
# 0   2022-12-11 2022-12-11         NaN              5.0
# 1   2022-11-26 2022-11-26        12.0            230.0
# 2   2022-09-15 2022-09-16        12.0             33.0
# 3   2022-09-15 2022-09-16        12.0             33.0
# 4   2022-09-02 2022-09-02         NaN          10937.0
# ..         ...        ...         ...              ...
# 130 2021-01-11 2021-01-12         NaN             22.0
# 131 2021-01-11 2021-01-12         NaN             22.0
# 132 2021-01-08 2021-01-12         5.0              NaN
# 133 2021-01-08 2021-01-12         5.0              NaN
# 134 2021-01-08 2021-01-12         5.0              NaN
#
#                         nuts3_region  ... nuts2_code  \
# 0                       Zadar county  ...       HR03
# 1    Casamicciola Terme municipality  ...       ITF3
# 2                    Ancona province  ...       ITI3
# 3                    Pesaro province  ...       ITI3
# 4                   Plovdiv province  ...       BG42
# ..                               ...  ...        ...
# 130               Jablanica District  ...       RS22
# 131               Jablanica District  ...       RS22
# 132                           Madrid  ...       ES30
# 133                  Málaga province  ...       ES61
# 134                Zaragoza province  ...       ES24
#
#                              nuts1_region nuts1_code                  cause  \
# 0                                Hrvatska        HR0                    NaN
# 1                                     Sud        ITF            heavy rains
# 2                             Centro (IT)        ITI            heavy rains
# 3                             Centro (IT)        ITI            heavy rains
# 4    Югозападна и Южна централна България        BG4            heavy rains
# ..                                    ...        ...                    ...
# 130                                   NaN        RS2            heavy rains
# 131                                   NaN        RS2            heavy rains
# 132                   Comunidad de Madrid        ES3  blizzard/winter storm
# 133                                   Sur        ES6  blizzard/winter storm
# 134                               Noreste        ES2  blizzard/winter storm
#
#          flood_type                           data_exists  \
# 0               NaN                     em-dat, floodlist
# 1             flood             em-dat, gdacs, copernicus
# 2    riverine flood                     copernicus,em-dat
# 3    riverine flood                     copernicus,em-dat
# 4    riverine flood  copernicus, floodlist, em-dat, glide
# ..              ...                                   ...
# 130             NaN                     em-dat, floodlist
# 131             NaN                     em-dat, floodlist
# 132             NaN                    copernicus, em-dat
# 133             NaN                    copernicus, em-dat
# 134             NaN                    copernicus, em-dat
#
#                                                sources  \
# 0                     em-dat, floodlist, floodlist.com
# 1                            em-dat, gdacs, copernicus
# 2           copernicus,em-dat, emergency.copernicus.eu
# 3           copernicus,em-dat, emergency.copernicus.eu
# 4    copernicus, floodlist, em-dat, glide, floodlis...
# ..                                                 ...
# 130                   em-dat, floodlist, floodlist.com
# 131                   em-dat, floodlist, floodlist.com
# 132            copernicus, em-dat, www.theguardian.com
# 133            copernicus, em-dat, www.theguardian.com
# 134            copernicus, em-dat, www.theguardian.com
#
#                                         notes  \
# 0                                         NaN
# 1           source for deaths copernicus essd
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 130                                       NaN
# 131  source of people affected from floodlist
# 132                                       NaN
# 133                                       NaN
# 134                                       NaN
#
#                                             reportLink nuts2_region_y
# 0    https://floodlist.com/europe/bosnia-croatia-fl...            NaN
# 1                                                  NaN            NaN
# 2    https://emergency.copernicus.eu/mapping/list-o...            NaN
# 3    https://emergency.copernicus.eu/mapping/list-o...            NaN
# 4    https://floodlist.com/europe/bulgaria-floods-p...            NaN
# ..                                                 ...            ...
# 130  https://floodlist.com/europe/serbia-bulgaria-a...            NaN
# 131  https://floodlist.com/europe/serbia-bulgaria-a...            NaN
# 132  https://www.theguardian.com/world/2021/jan/10/...  Madrid region
# 133  https://www.theguardian.com/world/2021/jan/10/...            NaN
# 134  https://www.theguardian.com/world/2021/jan/10/...            NaN
#
# [135 rows x 24 columns]

# %%
df_copernicus_nuts1 = df_copernicus[["nuts1_region", "nuts1_code"]].drop_duplicates().copy()

# %%
df_emdat = pd.merge(df_emdat, df_copernicus_nuts1, on='nuts1_code', how='left')

# %%
df_emdat.to_excel("df_emdat_test_regions.xlsx", index=False)

# %% [markdown]
# ### fix the english versions

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 135 non-null    object
#  1   flood_name                         0 non-null      float64
#  2   flood_info                         78 non-null     object
#  3   year                               135 non-null    int64
#  4   country                            135 non-null    object
#  5   start_date                         135 non-null    datetime64[ns]
#  6   end_date                           121 non-null    datetime64[ns]
#  7   fatalities                         80 non-null     float64
#  8   people_affected                    74 non-null     float64
#  9   nuts3_region                       108 non-null    object
#  10  nuts3_code                         108 non-null    object
#  11  nuts3_region_urban_rural_typology  101 non-null    object
#  12  nuts3_coastal_regions              101 non-null    object
#  13  nuts2_region_x                     120 non-null    object
#  14  nuts2_code                         127 non-null    object
#  15  nuts1_region_x                     121 non-null    object
#  16  nuts1_code                         127 non-null    object
#  17  cause                              115 non-null    object
#  18  flood_type                         102 non-null    object
#  19  data_exists                        135 non-null    object
#  20  sources                            135 non-null    object
#  21  notes                              27 non-null     object
#  22  reportLink                         81 non-null     object
#  23  nuts2_region_y                     24 non-null     object
#  24  nuts1_region_y                     54 non-null     object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(19)
# memory usage: 26.5+ KB

# %% [markdown]
# ##### see the empty nuts2 regions from the merge

# %%
df_nuts_2_empty = df_emdat[df_emdat["nuts2_region_y"].isna()].copy()

# %%
df_nuts_2_empty['nuts2_region_x'].unique()
# Out:
# array(['Jadranska Hrvatska', 'Campania', 'Marche', 'Южен централен',
#        'Veneto', 'Provincia Autonoma di Trento', 'Arnsberg', 'Aragón',
#        'Comunidad Foral de Navarra', 'La Rioja', 'País Vasco',
#        'Aquitaine', 'Principado de Asturias', 'Cantabria', 'Sicilia',
#        'Languedoc-Roussillon', 'Cataluña', 'Bourgogne', 'Auvergne',
#        'Lorraine', 'Wien', 'Salzburg', 'Steiermark', 'Tirol',
#        'Franche-Comté', 'Limburg (NL)', 'Prov. Liège', 'Prov. Namur',
#        'Prov. Luxembourg (BE)', 'Prov. Brabant wallon',
#        'Prov. Limburg (BE)', 'Prov. Hainaut', nan, 'Střední Čechy',
#        'Jihozápad', 'Severozápad', 'Praha', 'Severovýchod', 'Koblenz',
#        'Köln', 'Düsseldorf', 'Thüringen', 'Kujawsko-pomorskie',
#        'Pomorskie', 'Warmińsko-mazurskie', 'Małopolskie', 'Podkarpackie',
#        'Picardie', 'Champagne-Ardenne', 'Nord-Est', 'Sud-Muntenia',
#        'Bucureşti-Ilfov', 'Vest', 'Centru', 'Stredné Slovensko',
#        'Východné Slovensko', 'Pohjois- ja Itä-Suomi', 'Münster',
#        'Darmstadt', 'Lazio', 'Югозападен', 'Andalucía'], dtype=object)

# %%
nuts2_english = {
    'Jadranska Hrvatska': 'Adriatic Croatia region',
    'Campania': 'Campania region',
    'Marche': 'Marche region',
    'Южен централен': 'South-Central Bulgaria region',
    'Veneto': 'Veneto region',
    'Provincia Autonoma di Trento': 'Trento province',
    'Arnsberg': 'Arnsberg region',
    'Aragón': 'Aragon region',
    'Comunidad Foral de Navarra': 'Navarre region',
    'La Rioja': 'La Rioja region',
    'País Vasco': 'Basque Country region',
    'Aquitaine': 'Aquitaine region',
    'Principado de Asturias': 'Asturias region',
    'Cantabria': 'Cantabria region',
    'Sicilia': 'Sicily region',
    'Languedoc-Roussillon': 'Languedoc-Roussillon region',
    'Cataluña': 'Catalonia region',
    'Bourgogne': 'Bourgogne region',
    'Auvergne': 'Auvergne region',
    'Lorraine': 'Lorraine region',
    'Wien': 'Vienna region',
    'Salzburg': 'Salzburg region',
    'Steiermark': 'Styria region',
    'Tirol': 'Tyrol region',
    'Franche-Comté': 'Franche-Comté region',
    'Limburg (NL)': 'Limburg region (Netherlands)',
    'Prov. Liège': 'Liège province',
    'Prov. Namur': 'Namur province',
    'Prov. Luxembourg (BE)': 'Luxembourg province (Belgium)',
    'Prov. Brabant wallon': 'Walloon Brabant province',
    'Prov. Limburg (BE)': 'Limburg province (Belgium)',
    'Prov. Hainaut': 'Hainaut province',
    'Střední Čechy': 'Central Bohemia region',
    'Jihozápad': 'Southwest Czechia region',
    'Severozápad': 'Northwest Czechia region',
    'Praha': 'Prague region',
    'Severovýchod': 'Northeast Czechia region',
    'Koblenz': 'Koblenz region',
    'Köln': 'Cologne region',
    'Düsseldorf': 'Düsseldorf region',
    'Thüringen': 'Thuringia region',
    'Kujawsko-pomorskie': 'Kuyavian-Pomeranian region',
    'Pomorskie': 'Pomeranian region',
    'Warmińsko-mazurskie': 'Warmian-Masurian region',
    'Małopolskie': 'Lesser Poland region',
    'Podkarpackie': 'Subcarpathian region',
    'Picardie': 'Picardie region',
    'Champagne-Ardenne': 'Champagne-Ardenne region',
    'Nord-Est': 'Northeast Romania region',
    'Sud-Muntenia': 'South Muntenia region',
    'Bucureşti-Ilfov': 'Bucharest-Ilfov region',
    'Vest': 'West Romania region',
    'Centru': 'Central Romania region',
    'Stredné Slovensko': 'Central Slovakia region',
    'Východné Slovensko': 'Eastern Slovakia region',
    'Pohjois- ja Itä-Suomi': 'Northern and Eastern Finland region',
    'Münster': 'Münster region',
    'Darmstadt': 'Darmstadt region',
    'Lazio': 'Lazio region',
    'Югозападен': 'Southwest Bulgaria region',
    'Andalucía': 'Andalusia region'
}

# %%
df_emdat["nuts2_region_y"] = df_emdat["nuts2_region_x"].apply(lambda x: nuts2_english.get(x, x))

# %%
df_emdat['nuts2_region_y'].unique()
# Out:
# array(['Adriatic Croatia region', 'Campania region', 'Marche region',
#        'South-Central Bulgaria region', 'Veneto region',
#        'Trento province', 'Arnsberg region', 'Comunitat Valenciana ',
#        'Aragon region', 'Navarre region', 'La Rioja region',
#        'Basque Country region', 'Aquitaine region', 'Nord-Pas de Calais',
#        'Asturias region', 'Cantabria region', 'Sicily region',
#        'Zahodna Slovenija', 'Languedoc-Roussillon region',
#        'Catalonia region', 'Castilla-La Mancha', 'Norra Mellansverige',
#        'Bourgogne region', 'Auvergne region', 'Lorraine region',
#        'Vienna region', 'Salzburg region', 'Styria region',
#        'Tyrol region', 'Franche-Comté region',
#        'Limburg region (Netherlands)', 'Liège province', 'Namur province',
#        'Luxembourg province (Belgium)', 'Walloon Brabant province',
#        'Limburg province (Belgium)', 'Hainaut province', nan,
#        'Central Bohemia region', 'Southwest Czechia region',
#        'Northwest Czechia region', 'Prague region',
#        'Northeast Czechia region', 'Oberbayern', 'Stuttgart',
#        'Koblenz region', 'Cologne region', 'Düsseldorf region',
#        'Thuringia region', 'Kuyavian-Pomeranian region',
#        'Pomeranian region', 'Warmian-Masurian region', 'Łódzkie',
#        'Śląskie', 'Lesser Poland region', 'Subcarpathian region',
#        'Picardie region', 'Champagne-Ardenne region',
#        'Northeast Romania region', 'Sud-Est', 'South Muntenia region',
#        'Bucharest-Ilfov region', 'West Romania region',
#        'Central Romania region', 'Central Slovakia region',
#        'Západné Slovensko', 'Eastern Slovakia region',
#        'Northern and Eastern Finland region', 'Münster region',
#        'Poitou-Charentes', 'Darmstadt region', 'Lazio region',
#        'Southwest Bulgaria region', 'Comunidad de Madrid',
#        'Andalusia region'], dtype=object)

# %%
df_emdat.rename(columns={'nuts2_region_y': 'nuts2_region'}, inplace=True)

# %%
df_nuts_1_empty = df_emdat[df_emdat["nuts1_region_y"].isna()].copy()

# %%
df_nuts_1_empty['nuts1_region_x'].unique()
# Out:
# array(['Sud', 'Югозападна и Южна централна България',
#        'Nordrhein-Westfalen', 'Noreste', 'Noroeste', 'Isole', 'Occitanie',
#        'Bourgogne-Franche-Comté', 'Auvergne-Rhône-Alpes', 'Grand Est',
#        'Westösterreich', 'Südösterreich', 'Zuid-Nederland',
#        'Région wallonne', nan, 'Rheinland-Pfalz', 'Thüringen',
#        'Makroregion północny', 'Makroregion wschodni',
#        'Macroregiunea Trei', 'Macroregiunea Patru', 'Macroregiunea Unu',
#        'Manner-Suomi', 'Pohjois- ja Itä-Suomi', 'Hessen', 'Sur'],
#       dtype=object)

# %%
df_emdat['nuts1_region_y'].unique()
# Out:
# array(['Croatia', nan, 'Central Italy', 'North-Eastern Italy',
#        'Eastern Spain', 'Nouvelle-Aquitaine', 'Hauts-de-France',
#        'Slovenia', 'Central Spain', 'Northern Sweden', 'Eastern Austria',
#        'Flemish Region', 'Czechia', 'Bavaria', 'Baden-Württemberg',
#        'Central Poland macroregion', 'Southern Poland Macroregion',
#        'Macroregion two (Romania)', 'Slovakia', 'Madrid region'],
#       dtype=object)

# %%
nuts1_english = {
    'Sud': 'Southern Italy',
    'Югозападна и Южна централна България': 'South-West and South-Central Bulgaria',
    'Nordrhein-Westfalen': 'North Rhine-Westphalia',
    'Noreste': 'Northeast Spain',
    'Noroeste': 'Northwest Spain',
    'Isole': 'Islands (Italy)',
    'Occitanie': 'Occitania',
    'Bourgogne-Franche-Comté': 'Bourgogne-Franche-Comté',
    'Auvergne-Rhône-Alpes': 'Auvergne-Rhône-Alpes',
    'Grand Est': 'Grand Est',
    'Westösterreich': 'Western Austria',
    'Südösterreich': 'Southern Austria',
    'Zuid-Nederland': 'Southern Netherlands',
    'Région wallonne': 'Walloon Region',
    'Rheinland-Pfalz': 'Rhineland-Palatinate',
    'Thüringen': 'Thuringia',
    'Makroregion północny': 'Northern Poland Macroregion',
    'Makroregion wschodni': 'Eastern Poland Macroregion',
    'Macroregiunea Trei': 'Macroregion three (Romania)',
    'Macroregiunea Patru': 'Macroregion four (Romania)',
    'Macroregiunea Unu': 'Macroregion one (Romania)',
    'Manner-Suomi': 'Mainland Finland',
    'Pohjois- ja Itä-Suomi': 'Northern and Eastern Finland',
    'Hessen': 'Hesse',
    'Sur': 'Southern Spain'
}

# %%
df_emdat["nuts1_region_y"] = df_emdat["nuts1_region_x"].apply(lambda x: nuts1_english.get(x, x))

# %%
df_emdat.rename(columns={'nuts1_region_y': 'nuts1_region'}, inplace=True)

# %%
df_emdat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   id                                 135 non-null    object
#  1   flood_name                         0 non-null      float64
#  2   flood_info                         78 non-null     object
#  3   year                               135 non-null    int64
#  4   country                            135 non-null    object
#  5   start_date                         135 non-null    datetime64[ns]
#  6   end_date                           121 non-null    datetime64[ns]
#  7   fatalities                         80 non-null     float64
#  8   people_affected                    74 non-null     float64
#  9   nuts3_region                       108 non-null    object
#  10  nuts3_code                         108 non-null    object
#  11  nuts3_region_urban_rural_typology  101 non-null    object
#  12  nuts3_coastal_regions              101 non-null    object
#  13  nuts2_region_x                     120 non-null    object
#  14  nuts2_code                         127 non-null    object
#  15  nuts1_region_x                     121 non-null    object
#  16  nuts1_code                         127 non-null    object
#  17  cause                              115 non-null    object
#  18  flood_type                         102 non-null    object
#  19  data_exists                        135 non-null    object
#  20  sources                            135 non-null    object
#  21  notes                              27 non-null     object
#  22  reportLink                         81 non-null     object
#  23  nuts2_region                       120 non-null    object
#  24  nuts1_region                       121 non-null    object
# dtypes: datetime64[ns](2), float64(3), int64(1), object(19)
# memory usage: 26.5+ KB

# %%
df_emdat.drop(columns=['nuts2_region_x', 'nuts1_region_x'], inplace=True)

# %% [markdown]
# ### re order again

# %%
df_emdat = df_emdat[[
    "id", "flood_name", "flood_info", "year", "country", "start_date", "end_date", "fatalities", "people_affected",
    "nuts3_region", "nuts3_code", "nuts3_region_urban_rural_typology", 
    "nuts3_coastal_regions", "nuts2_region", "nuts2_code", "nuts1_region", "nuts1_code", "cause", "flood_type", 
    "data_exists", "sources", "notes", "reportLink"
]]

# %%
df_emdat.to_excel("df_emdat_final_for_merge_decade.xlsx", index=False)

# %% [markdown]
# # Concatinate the first two (to avoid translation errors on hanze)

# %%
df_copernicus_and_emdat = pd.concat([df_copernicus, df_emdat], join="outer", ignore_index=True)
# Out:
# C:\Users\kwnst\AppData\Local\Temp\ipykernel_15576\1474454565.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_copernicus_and_emdat = pd.concat([df_copernicus, df_emdat], join="outer", ignore_index=True)

# %%
df_copernicus_and_emdat
# Out:
#                 id                                         flood_name  \
# 0          EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 1          EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 2          EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 3          EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# 4          EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# ..             ...                                                ...
# 198  2021-0020-SRB                                                NaN
# 199  2021-0020-SRB                                                NaN
# 200  2021-0016-ESP                                                NaN
# 201  2021-0016-ESP                                                NaN
# 202  2021-0016-ESP                                                NaN
#
#                                             flood_info  year country  \
# 0    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 1    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 2    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 3    Italy has been hit in recent days by a severe ...  2024   Italy
# 4    Italy has been hit in recent days by a severe ...  2024   Italy
# ..                                                 ...   ...     ...
# 198  In Serbia, the Ministry of Interior reported a...  2021  Serbia
# 199  In Serbia, the Ministry of Interior reported a...  2021  Serbia
# 200                                                NaN  2021   Spain
# 201                                                NaN  2021   Spain
# 202                                                NaN  2021   Spain
#
#              start_date   end_date  fatalities  people_affected  \
# 0   2024-10-29 14:30:00        NaT       285.0         190090.0
# 1   2024-10-29 14:30:00        NaT       285.0         190090.0
# 2   2024-10-29 14:30:00        NaT       285.0         190090.0
# 3   2024-10-20 12:00:00        NaT         1.0            670.0
# 4   2024-10-20 12:00:00        NaT         1.0            670.0
# ..                  ...        ...         ...              ...
# 198 2021-01-11 00:00:00 2021-01-12         NaN             22.0
# 199 2021-01-11 00:00:00 2021-01-12         NaN             22.0
# 200 2021-01-08 00:00:00 2021-01-12         5.0              NaN
# 201 2021-01-08 00:00:00 2021-01-12         5.0              NaN
# 202 2021-01-08 00:00:00 2021-01-12         5.0              NaN
#
#                nuts3_region  ...               nuts2_region nuts2_code  \
# 0        Valencia province   ...            Valencia region       ES52
# 1         Albacete province  ...  Castilla-La Mancha region       ES42
# 2        Castellón province  ...            Valencia region       ES52
# 3    Reggio Emilia province  ...      Emilia-Romagna region       ITH5
# 4           Modena province  ...      Emilia-Romagna region       ITH5
# ..                      ...  ...                        ...        ...
# 198      Jablanica District  ...                        NaN       RS22
# 199      Jablanica District  ...                        NaN       RS22
# 200                  Madrid  ...        Comunidad de Madrid       ES30
# 201         Málaga province  ...           Andalusia region       ES61
# 202       Zaragoza province  ...              Aragon region       ES24
#
#             nuts1_region nuts1_code                  cause flood_type  \
# 0          Eastern Spain        ES5                   None       None
# 1          Central Spain        ES4                   None       None
# 2          Eastern Spain        ES5                   None       None
# 3    North-Eastern Italy        ITH                   None       None
# 4    North-Eastern Italy        ITH                   None       None
# ..                   ...        ...                    ...        ...
# 198                  NaN        RS2            heavy rains        NaN
# 199                  NaN        RS2            heavy rains        NaN
# 200  Comunidad de Madrid        ES3  blizzard/winter storm        NaN
# 201       Southern Spain        ES6  blizzard/winter storm        NaN
# 202      Northeast Spain        ES2  blizzard/winter storm        NaN
#
#             data_exists                                  sources  \
# 0            copernicus           Copernicus, GDACS ID FL1102983
# 1            copernicus           Copernicus, GDACS ID FL1102983
# 2            copernicus           Copernicus, GDACS ID FL1102983
# 3            copernicus           Copernicus, GDACS ID FL1102961
# 4            copernicus           Copernicus, GDACS ID FL1102961
# ..                  ...                                      ...
# 198   em-dat, floodlist         em-dat, floodlist, floodlist.com
# 199   em-dat, floodlist         em-dat, floodlist, floodlist.com
# 200  copernicus, em-dat  copernicus, em-dat, www.theguardian.com
# 201  copernicus, em-dat  copernicus, em-dat, www.theguardian.com
# 202  copernicus, em-dat  copernicus, em-dat, www.theguardian.com
#
#                                         notes  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 198                                       NaN
# 199  source of people affected from floodlist
# 200                                       NaN
# 201                                       NaN
# 202                                       NaN
#
#                                             reportLink
# 0    https://storymaps.arcgis.com/stories/9ff57e932...
# 1    https://storymaps.arcgis.com/stories/9ff57e932...
# 2    https://storymaps.arcgis.com/stories/9ff57e932...
# 3    https://storymaps.arcgis.com/stories/b95e2210e...
# 4    https://storymaps.arcgis.com/stories/b95e2210e...
# ..                                                 ...
# 198  https://floodlist.com/europe/serbia-bulgaria-a...
# 199  https://floodlist.com/europe/serbia-bulgaria-a...
# 200  https://www.theguardian.com/world/2021/jan/10/...
# 201  https://www.theguardian.com/world/2021/jan/10/...
# 202  https://www.theguardian.com/world/2021/jan/10/...
#
# [203 rows x 23 columns]

# %%
df_copernicus_and_emdat.to_excel("df_copernicus_and_emdat_final_for_merge_decade.xlsx", index=False)

# %% [markdown]
# # Let's do the Hanze dataset 2020-2014 -> final_hanze_dataset_2020_2014

# %%
df_hanze = pd.read_excel("final_hanze_dataset_2020_2014.xlsx")
df_hanze
# Out:
#        id  year  subregion_europe country  start_date    end_date  \
# 0    2114  2020               NaN  France   1/20/2020   1/23/2020
# 1    2114  2020               NaN  France   1/20/2020   1/23/2020
# 2    2329  2020               NaN   Spain   1/20/2020   1/23/2020
# 3    2329  2020               NaN   Spain   1/20/2020   1/23/2020
# 4    2329  2020               NaN   Spain   1/20/2020   1/23/2020
# ..    ...   ...               ...     ...         ...         ...
# 667   271  2014               NaN  France  11/25/2014   12/5/2014
# 668  2312  2014               NaN   Spain  11/30/2014  11/30/2014
# 669  2130  2014               NaN  Greece   12/4/2014  12/14/2014
# 670  2130  2014               NaN  Greece   12/4/2014  12/14/2014
# 671  2130  2014               NaN  Greece   12/4/2014  12/14/2014
#
#               type             nuts3_name_2024 nuts3_code_2021  \
# 0            River                        Aude           FRJ11
# 1            River         Pyrénées-Orientales           FRJ15
# 2    River/Coastal                   Barcelona           ES511
# 3    River/Coastal                      Girona           ES512
# 4    River/Coastal                   Tarragona           ES514
# ..             ...                         ...             ...
# 667          River                 Haute-Corse           FRM02
# 668          Flash                      Girona           ES512
# 669          River               Έβρος / Evros           EL511
# 670          River  Θεσσαλονίκη / Thessaloniki           EL522
# 671          River             Κιλκίς / Kilkis           EL523
#
#      nuts3_2024_urban_rural_typology  ...  \
# 0                                NaN  ...
# 1                                NaN  ...
# 2                                NaN  ...
# 3                                NaN  ...
# 4                                NaN  ...
# ..                               ...  ...
# 667                              NaN  ...
# 668                              NaN  ...
# 669                              NaN  ...
# 670                              NaN  ...
# 671                              NaN  ...
#
#                                        nuts2_name_2024 nuts2_code_2021  \
# 0                                 Languedoc-Roussillon            FRJ1
# 1                                 Languedoc-Roussillon            FRJ1
# 2                                             Cataluña            ES51
# 3                                             Cataluña            ES51
# 4                                             Cataluña            ES51
# ..                                                 ...             ...
# 667                                              Corse            FRM0
# 668                                           Cataluña            ES51
# 669  Aνατολική Μακεδονία, Θράκη / Anatoliki Makedon...            EL51
# 670            Κεντρική Μακεδονία / Kentriki Makedonia            EL52
# 671            Κεντρική Μακεδονία / Kentriki Makedonia            EL52
#
#     regions_nuts_2_en  fatalities  people_affected  \
# 0                 NaN           0           1750.0
# 1                 NaN           0           1750.0
# 2                 NaN           7              NaN
# 3                 NaN           7              NaN
# 4                 NaN           7              NaN
# ..                ...         ...              ...
# 667               NaN           6           3000.0
# 668               NaN           1              NaN
# 669               NaN           5              NaN
# 670               NaN           5              NaN
# 671               NaN           5              NaN
#
#                                                  cause data_exists  \
# 0                Heavy rainfall up to 379 mm in 3 days       HANZE
# 1                Heavy rainfall up to 379 mm in 3 days       HANZE
# 2          Storm surge and heavy rainfall up to 227 mm       HANZE
# 3          Storm surge and heavy rainfall up to 227 mm       HANZE
# 4          Storm surge and heavy rainfall up to 227 mm       HANZE
# ..                                                 ...         ...
# 667  Heavy rainfall throughout November, culminatin...       HANZE
# 668              Extreme rainfall up to 240 mm in 24 h       HANZE
# 669                Heavy rainfall up to 120 mm in 24 h       HANZE
# 670                Heavy rainfall up to 120 mm in 24 h       HANZE
# 671                Heavy rainfall up to 120 mm in 24 h       HANZE
#
#                                                sources  \
# 0    FloodList (2022); European Commission (2022); ...
# 1    FloodList (2022); European Commission (2022); ...
# 2    FloodList (2022); European Commission (2022); ...
# 3    FloodList (2022); European Commission (2022); ...
# 4    FloodList (2022); European Commission (2022); ...
# ..                                                 ...
# 667  CRED (2023); Brakenridge (2022); Meteo France ...
# 668  Papagiannaki et al. (2022); Noticias de Navarr...
# 669  Papagiannaki et al. (2022); Brakenridge (2022)...
# 670  Papagiannaki et al. (2022); Brakenridge (2022)...
# 671  Papagiannaki et al. (2022); Brakenridge (2022)...
#
#                                                  notes losses_euro_2020
# 0                                                  NaN              NaN
# 1                                                  NaN              NaN
# 2    Claimed economic loss (45m EUR attributed to c...      145400000.0
# 3    Claimed economic loss (45m EUR attributed to c...      145400000.0
# 4    Claimed economic loss (45m EUR attributed to c...      145400000.0
# ..                                                 ...              ...
# 667                                                NaN      244346990.0
# 668                                                NaN              NaN
# 669                                                NaN              NaN
# 670                                                NaN              NaN
# 671                                                NaN              NaN
#
# [672 rows x 21 columns]

# %%
df_hanze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   id                               672 non-null    int64
#  1   year                             672 non-null    int64
#  2   subregion_europe                 0 non-null      float64
#  3   country                          672 non-null    object
#  4   start_date                       672 non-null    object
#  5   end_date                         672 non-null    object
#  6   type                             672 non-null    object
#  7   nuts3_name_2024                  672 non-null    object
#  8   nuts3_code_2021                  672 non-null    object
#  9   nuts3_2024_urban_rural_typology  0 non-null      float64
#  10  nuts3_2024_coastal_regions       0 non-null      float64
#  11  nuts2_name_2024                  672 non-null    object
#  12  nuts2_code_2021                  672 non-null    object
#  13  regions_nuts_2_en                0 non-null      float64
#  14  fatalities                       672 non-null    int64
#  15  people_affected                  298 non-null    float64
#  16  cause                            672 non-null    object
#  17  data_exists                      672 non-null    object
#  18  sources                          672 non-null    object
#  19  notes                            283 non-null    object
#  20  losses_euro_2020                 435 non-null    float64
# dtypes: float64(6), int64(3), object(12)
# memory usage: 110.4+ KB

# %% [markdown]
# ## rename and drop

# %%
df_hanze.rename(columns={
    "type": "flood_type",
    "nuts3_name_2024": "nuts3_region",
    "nuts3_code_2021": "nuts3_code_2021",
}, inplace=True)

# %%
df_hanze.drop(columns=['subregion_europe','losses_euro_2020', 'nuts3_2024_urban_rural_typology', 'nuts3_2024_coastal_regions', 'regions_nuts_2_en',
                      'nuts2_name_2024', 'nuts2_code_2021'], inplace=True)

# %% [markdown]
# ## Hanze has an issue, it has old (2021) codes. We will use the excel that has both codes and then we will move forward

# %%
df_nuts_regions_both_codes = pd.read_excel("nuts_codes_from_NUTS2021-NUTS2024_with_both_2021_2024_codes.xlsx")
df_nuts_regions_both_codes
# Out:
#          # Country Code Code 2021 Code 2024  \
# 0        1           BE        BE        BE
# 1        2           BE       BE1       BE1
# 2        3           BE      BE10      BE10
# 3        4           BE     BE100     BE100
# 4        5           BE       BE2       BE2
# ...    ...          ...       ...       ...
# 1642  1643           SE     SE331     SE331
# 1643  1644           SE     SE332     SE332
# 1644  1645           SE       SEZ       SEZ
# 1645  1646           SE      SEZZ      SEZZ
# 1646  1647           SE     SEZZZ     SEZZZ
#
#      NUTS level 1 \n(italics: NUTS 2021 else NUTS 2024)  \
# 0                                                   NaN
# 1     Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2                                                   NaN
# 3                                                   NaN
# 4                                         Vlaams Gewest
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                 Extra-Regio NUTS 1
# 1645                                                NaN
# 1646                                                NaN
#
#      NUTS level 2 \n(italics: NUTS 2021 else NUTS 2024)  \
# 0                                                   NaN
# 1                                                   NaN
# 2     Région de Bruxelles-Capitale/Brussels Hoofdste...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1642                                                NaN
# 1643                                                NaN
# 1644                                                NaN
# 1645                                 Extra-Regio NUTS 2
# 1646                                                NaN
#
#      NUTS level 3 \n(italics: NUTS 2021 else NUTS 2024) Change  NUTS level  \
# 0                                                   NaN    NaN           0
# 1                                                   NaN    NaN           1
# 2                                                   NaN    NaN           2
# 3     Arr. de Bruxelles-Capitale/Arr. Brussel-Hoofdstad    NaN           3
# 4                                                   NaN    NaN           1
# ...                                                 ...    ...         ...
# 1642                                  Västerbottens län    NaN           3
# 1643                                    Norrbottens län    NaN           3
# 1644                                                NaN    NaN           1
# 1645                                                NaN    NaN           2
# 1646                                 Extra-Regio NUTS 3    NaN           3
#
#       Country order  Region order (NUTS 2021)  Region order (NUTS 2024)
# 0                 1                       1.0                       1.0
# 1                 1                       2.0                       2.0
# 2                 1                       3.0                       3.0
# 3                 1                       4.0                       4.0
# 4                 1                       5.0                       5.0
# ...             ...                       ...                       ...
# 1642             27                    1604.0                    1605.0
# 1643             27                    1605.0                    1606.0
# 1644             27                    1606.0                    1607.0
# 1645             27                    1607.0                    1608.0
# 1646             27                    1608.0                    1609.0
#
# [1647 rows x 12 columns]

# %%
df_nuts_regions_both_codes['Change'].value_counts()
# Out:
# Change
# New region        39
# Boundary shift    34
# Code change       16
# art. 5(2a)         6
# Name change        4
# Merged             2
# Split              2
# Name: count, dtype: int64

# %%
df_nuts_regions_both_codes.drop(columns=['Country Code', 'Country order', '#', 'NUTS level', 'Region order (NUTS 2021)', 'Region order (NUTS 2024)'], inplace=True)

# %%
df_hanze = pd.merge(df_hanze, df_nuts_regions_both_codes, left_on='nuts3_code_2021', right_on='Code 2021', how='left')

# %%
df_hanze['Change'].value_counts()
# Out:
# Change
# art. 5(2a)        4
# Name change       3
# Code change       2
# Boundary shift    1
# Name: count, dtype: int64

# %%
df_hanze[df_hanze['Change'] == 'Name change']
# Out:
#        id  year country  start_date    end_date flood_type  \
# 229  2166  2017   Italy   1/21/2017   1/22/2017      Flash
# 378  1001  2016   Italy  11/19/2016  11/25/2016      River
# 487  1000  2015   Italy  10/31/2015   11/2/2015      River
#
#            nuts3_region nuts3_code_2021  fatalities  people_affected  \
# 229  Reggio di Calabria           ITF65           1              NaN
# 378  Reggio di Calabria           ITF65           4              NaN
# 487  Reggio di Calabria           ITF65           1              NaN
#
#                                                 cause data_exists  \
# 229             Extreme rainfall up to 149 mm in 15 h       HANZE
# 378  Heavy rainfall up to 583 mm in 24 h and snowfall       HANZE
# 487             Heavy rainfall up to 720 mm in 3 days       HANZE
#
#                                                sources  \
# 229  FloodList (2022); Papagiannaki et al. (2022); ...
# 378  FloodList (2022); European Commission (2022); ...
# 487  CRED (2023); ISPRA (2016); FloodList (2022); P...
#
#                                      notes Code 2021 Code 2024  \
# 229          Also windstorm and landslides     ITF65     ITF65
# 378  In Sicilia, two waves of flash floods     ITF65     ITF65
# 487       Losses also in Sicilia (no data)     ITF65     ITF65
#
#     NUTS level 1 \n(italics: NUTS 2021 else NUTS 2024)  \
# 229                                                NaN
# 378                                                NaN
# 487                                                NaN
#
#     NUTS level 2 \n(italics: NUTS 2021 else NUTS 2024)  \
# 229                                                NaN
# 378                                                NaN
# 487                                                NaN
#
#     NUTS level 3 \n(italics: NUTS 2021 else NUTS 2024)       Change
# 229                                    Reggio Calabria  Name change
# 378                                    Reggio Calabria  Name change
# 487                                    Reggio Calabria  Name change

# %%
df_hanze[df_hanze['Change'] == 'Code change']
# Out:
#        id  year   country start_date   end_date flood_type       nuts3_region  \
# 279  2240  2016  Portugal  2/12/2016  2/13/2016      Flash   Região de Aveiro
# 280  2240  2016  Portugal  2/12/2016  2/13/2016      Flash  Região de Coimbra
#
#     nuts3_code_2021  fatalities  people_affected  \
# 279           PT16D           1              NaN
# 280           PT16E           1              NaN
#
#                                    cause data_exists           sources notes  \
# 279  Extreme rainfall up to 50 mm in 6 h       HANZE  FloodList (2022)   NaN
# 280  Extreme rainfall up to 50 mm in 6 h       HANZE  FloodList (2022)   NaN
#
#     Code 2021 Code 2024 NUTS level 1 \n(italics: NUTS 2021 else NUTS 2024)  \
# 279     PT16D     PT191                                                NaN
# 280     PT16E     PT192                                                NaN
#
#     NUTS level 2 \n(italics: NUTS 2021 else NUTS 2024)  \
# 279                                                NaN
# 280                                                NaN
#
#     NUTS level 3 \n(italics: NUTS 2021 else NUTS 2024)       Change
# 279                                   Região de Aveiro  Code change
# 280                                  Região de Coimbra  Code change

# %% [markdown]
# ## I'll keep the names hanze have which are better and full, just change the one official difference in the name.

# %%
df_hanze['nuts3_region'] = df_hanze['nuts3_region'].replace('Reggio di Calabria', 'Reggio Calabria')

# %% [markdown]
# ## drop the columns you don't need

# %%
df_hanze.drop(columns=['Code 2021', 'nuts3_code_2021', 'NUTS level 1 \n(italics: NUTS 2021 else NUTS 2024)', 'NUTS level 2 \n(italics: NUTS 2021 else NUTS 2024)', 'NUTS level 3 \n(italics: NUTS 2021 else NUTS 2024)', 'Change'], inplace=True)

# %%
df_hanze.rename(columns={'Code 2024': 'nuts3_code'}, inplace=True)

# %% [markdown]
# ## Create the urban - rural and coastal typologies

# %%
df_nuts3_typologies = pd.read_excel("nuts3_regions_2024_typologies.xlsx")

# %%
df_hanze = pd.merge(df_hanze, df_nuts3_typologies, left_on='nuts3_code', right_on='NUTS-3 Code', how='left')
df_hanze
# Out:
#        id  year country  start_date    end_date     flood_type  \
# 0    2114  2020  France   1/20/2020   1/23/2020          River
# 1    2114  2020  France   1/20/2020   1/23/2020          River
# 2    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 3    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 4    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# ..    ...   ...     ...         ...         ...            ...
# 667   271  2014  France  11/25/2014   12/5/2014          River
# 668  2312  2014   Spain  11/30/2014  11/30/2014          Flash
# 669  2130  2014  Greece   12/4/2014  12/14/2014          River
# 670  2130  2014  Greece   12/4/2014  12/14/2014          River
# 671  2130  2014  Greece   12/4/2014  12/14/2014          River
#
#                    nuts3_region  fatalities  people_affected  \
# 0                          Aude           0           1750.0
# 1           Pyrénées-Orientales           0           1750.0
# 2                     Barcelona           7              NaN
# 3                        Girona           7              NaN
# 4                     Tarragona           7              NaN
# ..                          ...         ...              ...
# 667                 Haute-Corse           6           3000.0
# 668                      Girona           1              NaN
# 669               Έβρος / Evros           5              NaN
# 670  Θεσσαλονίκη / Thessaloniki           5              NaN
# 671             Κιλκίς / Kilkis           5              NaN
#
#                                                  cause  ... Country code  \
# 0                Heavy rainfall up to 379 mm in 3 days  ...           FR
# 1                Heavy rainfall up to 379 mm in 3 days  ...           FR
# 2          Storm surge and heavy rainfall up to 227 mm  ...           ES
# 3          Storm surge and heavy rainfall up to 227 mm  ...           ES
# 4          Storm surge and heavy rainfall up to 227 mm  ...           ES
# ..                                                 ...  ...          ...
# 667  Heavy rainfall throughout November, culminatin...  ...           FR
# 668              Extreme rainfall up to 240 mm in 24 h  ...           ES
# 669                Heavy rainfall up to 120 mm in 24 h  ...           EL
# 670                Heavy rainfall up to 120 mm in 24 h  ...           EL
# 671                Heavy rainfall up to 120 mm in 24 h  ...           EL
#
#     NUTS-3 Code         NUTS-3 label Urban-Rural typology Coastal regions  \
# 0         FRJ11                 Aude  predominantly rural         coastal
# 1         FRJ15  Pyrénées-Orientales         intermediate         coastal
# 2         ES511            Barcelona  predominantly urban         coastal
# 3         ES512               Girona         intermediate         coastal
# 4         ES514            Tarragona         intermediate         coastal
# ..          ...                  ...                  ...             ...
# 667       FRM02          Haute-Corse  predominantly rural         coastal
# 668       ES512               Girona         intermediate         coastal
# 669       EL511                Έβρος         intermediate         coastal
# 670       EL522          Θεσσαλονίκη  predominantly urban         coastal
# 671       EL523               Κιλκίς  predominantly rural         coastal
#
#     Metropolitan regions Border regions Island regions Mountanious regions  \
# 0                    NaN            NaN            NaN                 NaN
# 1                    NaN            NaN            NaN                 NaN
# 2                    NaN            NaN            NaN                 NaN
# 3                    NaN            NaN            NaN                 NaN
# 4                    NaN            NaN            NaN                 NaN
# ..                   ...            ...            ...                 ...
# 667                  NaN            NaN            NaN                 NaN
# 668                  NaN            NaN            NaN                 NaN
# 669                  NaN            NaN            NaN                 NaN
# 670                  NaN            NaN            NaN                 NaN
# 671                  NaN            NaN            NaN                 NaN
#
#      Capital regions
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ..               ...
# 667              NaN
# 668              NaN
# 669              NaN
# 670              NaN
# 671              NaN
#
# [672 rows x 24 columns]

# %%
df_hanze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    672 non-null    int64
#  1   year                  672 non-null    int64
#  2   country               672 non-null    object
#  3   start_date            672 non-null    object
#  4   end_date              672 non-null    object
#  5   flood_type            672 non-null    object
#  6   nuts3_region          672 non-null    object
#  7   fatalities            672 non-null    int64
#  8   people_affected       298 non-null    float64
#  9   cause                 672 non-null    object
#  10  data_exists           672 non-null    object
#  11  sources               672 non-null    object
#  12  notes                 283 non-null    object
#  13  nuts3_code            619 non-null    object
#  14  Country code          619 non-null    object
#  15  NUTS-3 Code           619 non-null    object
#  16  NUTS-3 label          619 non-null    object
#  17  Urban-Rural typology  619 non-null    object
#  18  Coastal regions       619 non-null    object
#  19  Metropolitan regions  0 non-null      float64
#  20  Border regions        0 non-null      float64
#  21  Island regions        0 non-null      float64
#  22  Mountanious regions   0 non-null      float64
#  23  Capital regions       8 non-null      object
# dtypes: float64(5), int64(3), object(16)
# memory usage: 126.1+ KB

# %%
df_hanze.drop(columns=['Country code', 'NUTS-3 label', 'Metropolitan regions', 'Border regions', 'Island regions', 'Mountanious regions', 'Capital regions'], inplace=True)

# %%
df_hanze.rename(columns={
    "Urban-Rural typology": "nuts3_region_urban_rural_typology",
    "Coastal regions": "nuts3_coastal_regions"
}, inplace=True)

# %% [markdown]
# ## Now merge with the NUTS2021-NUTS2024 dataset to get the nuts 2 and nuts 1 code and names

# %% [markdown]
# #### first create code columns and then merge

# %%
df_nuts_regions = pd.read_excel("all_nuts_2024_sheet_from_NUTS2021-NUTS2024.xlsx")

# %%
df_hanze['nuts2_code'] = df_hanze['nuts3_code'].apply(lambda x: x[:-1] if pd.notna(x) else None)

# %%
df_hanze = pd.merge(df_hanze, df_nuts_regions, left_on='nuts2_code', right_on='NUTS Code', how='left')

# %%
df_hanze
# Out:
#        id  year country  start_date    end_date     flood_type  \
# 0    2114  2020  France   1/20/2020   1/23/2020          River
# 1    2114  2020  France   1/20/2020   1/23/2020          River
# 2    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 3    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 4    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# ..    ...   ...     ...         ...         ...            ...
# 667   271  2014  France  11/25/2014   12/5/2014          River
# 668  2312  2014   Spain  11/30/2014  11/30/2014          Flash
# 669  2130  2014  Greece   12/4/2014  12/14/2014          River
# 670  2130  2014  Greece   12/4/2014  12/14/2014          River
# 671  2130  2014  Greece   12/4/2014  12/14/2014          River
#
#                    nuts3_region  fatalities  people_affected  \
# 0                          Aude           0           1750.0
# 1           Pyrénées-Orientales           0           1750.0
# 2                     Barcelona           7              NaN
# 3                        Girona           7              NaN
# 4                     Tarragona           7              NaN
# ..                          ...         ...              ...
# 667                 Haute-Corse           6           3000.0
# 668                      Girona           1              NaN
# 669               Έβρος / Evros           5              NaN
# 670  Θεσσαλονίκη / Thessaloniki           5              NaN
# 671             Κιλκίς / Kilkis           5              NaN
#
#                                                  cause  ... NUTS-3 Code  \
# 0                Heavy rainfall up to 379 mm in 3 days  ...       FRJ11
# 1                Heavy rainfall up to 379 mm in 3 days  ...       FRJ15
# 2          Storm surge and heavy rainfall up to 227 mm  ...       ES511
# 3          Storm surge and heavy rainfall up to 227 mm  ...       ES512
# 4          Storm surge and heavy rainfall up to 227 mm  ...       ES514
# ..                                                 ...  ...         ...
# 667  Heavy rainfall throughout November, culminatin...  ...       FRM02
# 668              Extreme rainfall up to 240 mm in 24 h  ...       ES512
# 669                Heavy rainfall up to 120 mm in 24 h  ...       EL511
# 670                Heavy rainfall up to 120 mm in 24 h  ...       EL522
# 671                Heavy rainfall up to 120 mm in 24 h  ...       EL523
#
#     nuts3_region_urban_rural_typology nuts3_coastal_regions nuts2_code  \
# 0                 predominantly rural               coastal       FRJ1
# 1                        intermediate               coastal       FRJ1
# 2                 predominantly urban               coastal       ES51
# 3                        intermediate               coastal       ES51
# 4                        intermediate               coastal       ES51
# ..                                ...                   ...        ...
# 667               predominantly rural               coastal       FRM0
# 668                      intermediate               coastal       ES51
# 669                      intermediate               coastal       EL51
# 670               predominantly urban               coastal       EL52
# 671               predominantly rural               coastal       EL52
#
#     Country code NUTS Code                  NUTS label NUTS level  \
# 0             FR      FRJ1        Languedoc-Roussillon        2.0
# 1             FR      FRJ1        Languedoc-Roussillon        2.0
# 2             ES      ES51                    Cataluña        2.0
# 3             ES      ES51                    Cataluña        2.0
# 4             ES      ES51                    Cataluña        2.0
# ..           ...       ...                         ...        ...
# 667           FR      FRM0                       Corse        2.0
# 668           ES      ES51                    Cataluña        2.0
# 669           EL      EL51  Aνατολική Μακεδονία, Θράκη        2.0
# 670           EL      EL52          Κεντρική Μακεδονία        2.0
# 671           EL      EL52          Κεντρική Μακεδονία        2.0
#
#     Country order      #
# 0            10.0  878.0
# 1            10.0  878.0
# 2             9.0  748.0
# 3             9.0  748.0
# 4             9.0  748.0
# ..            ...    ...
# 667          10.0  917.0
# 668           9.0  748.0
# 669           8.0  652.0
# 670           8.0  658.0
# 671           8.0  658.0
#
# [672 rows x 24 columns]

# %%
df_hanze.rename(columns={'NUTS label': 'nuts2_region'}, inplace=True)

# %%
df_hanze.drop(columns=['NUTS-3 Code', 'NUTS Code', 'Country code', 'NUTS level', '#', 'Country order'], inplace=True)

# %%
df_hanze['nuts1_code'] = df_hanze['nuts2_code'].apply(lambda x: x[:-1] if pd.notna(x) else None)

# %%
df_hanze = pd.merge(df_hanze, df_nuts_regions, left_on='nuts1_code', right_on='NUTS Code', how='left')

# %%
df_hanze.rename(columns={'NUTS label': 'nuts1_region'}, inplace=True)

# %%
df_hanze.drop(columns=['NUTS Code', 'Country code', 'NUTS level', '#', 'Country order'], inplace=True)

# %% [markdown]
# ## Fix sources, reportLink

# %%
df_hanze['sources'] = df_hanze['sources'].apply(lambda x: f"HANZE ({x})" if pd.notna(x) and x != "" else "HANZE")

# %%
df_hanze['reportLink'] = "https://naturalhazards.eu/database, https://zenodo.org/records/11259233"

# %%
df_hanze['flood_name'] = df_hanze.apply(lambda x: f"Flood in {x['country']}, on {x['start_date']}", axis=1)
df_hanze['flood_info'] = df_hanze['cause']
df_hanze
# Out:
#        id  year country  start_date    end_date     flood_type  \
# 0    2114  2020  France   1/20/2020   1/23/2020          River
# 1    2114  2020  France   1/20/2020   1/23/2020          River
# 2    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 3    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# 4    2329  2020   Spain   1/20/2020   1/23/2020  River/Coastal
# ..    ...   ...     ...         ...         ...            ...
# 667   271  2014  France  11/25/2014   12/5/2014          River
# 668  2312  2014   Spain  11/30/2014  11/30/2014          Flash
# 669  2130  2014  Greece   12/4/2014  12/14/2014          River
# 670  2130  2014  Greece   12/4/2014  12/14/2014          River
# 671  2130  2014  Greece   12/4/2014  12/14/2014          River
#
#                    nuts3_region  fatalities  people_affected  \
# 0                          Aude           0           1750.0
# 1           Pyrénées-Orientales           0           1750.0
# 2                     Barcelona           7              NaN
# 3                        Girona           7              NaN
# 4                     Tarragona           7              NaN
# ..                          ...         ...              ...
# 667                 Haute-Corse           6           3000.0
# 668                      Girona           1              NaN
# 669               Έβρος / Evros           5              NaN
# 670  Θεσσαλονίκη / Thessaloniki           5              NaN
# 671             Κιλκίς / Kilkis           5              NaN
#
#                                                  cause  ... nuts3_code  \
# 0                Heavy rainfall up to 379 mm in 3 days  ...      FRJ11
# 1                Heavy rainfall up to 379 mm in 3 days  ...      FRJ15
# 2          Storm surge and heavy rainfall up to 227 mm  ...      ES511
# 3          Storm surge and heavy rainfall up to 227 mm  ...      ES512
# 4          Storm surge and heavy rainfall up to 227 mm  ...      ES514
# ..                                                 ...  ...        ...
# 667  Heavy rainfall throughout November, culminatin...  ...      FRM02
# 668              Extreme rainfall up to 240 mm in 24 h  ...      ES512
# 669                Heavy rainfall up to 120 mm in 24 h  ...      EL511
# 670                Heavy rainfall up to 120 mm in 24 h  ...      EL522
# 671                Heavy rainfall up to 120 mm in 24 h  ...      EL523
#
#     nuts3_region_urban_rural_typology nuts3_coastal_regions nuts2_code  \
# 0                 predominantly rural               coastal       FRJ1
# 1                        intermediate               coastal       FRJ1
# 2                 predominantly urban               coastal       ES51
# 3                        intermediate               coastal       ES51
# 4                        intermediate               coastal       ES51
# ..                                ...                   ...        ...
# 667               predominantly rural               coastal       FRM0
# 668                      intermediate               coastal       ES51
# 669                      intermediate               coastal       EL51
# 670               predominantly urban               coastal       EL52
# 671               predominantly rural               coastal       EL52
#
#                    nuts2_region nuts1_code   nuts1_region  \
# 0          Languedoc-Roussillon        FRJ      Occitanie
# 1          Languedoc-Roussillon        FRJ      Occitanie
# 2                      Cataluña        ES5           Este
# 3                      Cataluña        ES5           Este
# 4                      Cataluña        ES5           Este
# ..                          ...        ...            ...
# 667                       Corse        FRM          Corse
# 668                    Cataluña        ES5           Este
# 669  Aνατολική Μακεδονία, Θράκη        EL5  Βόρεια Ελλάδα
# 670          Κεντρική Μακεδονία        EL5  Βόρεια Ελλάδα
# 671          Κεντρική Μακεδονία        EL5  Βόρεια Ελλάδα
#
#                                             reportLink  \
# 0    https://naturalhazards.eu/database, https://ze...
# 1    https://naturalhazards.eu/database, https://ze...
# 2    https://naturalhazards.eu/database, https://ze...
# 3    https://naturalhazards.eu/database, https://ze...
# 4    https://naturalhazards.eu/database, https://ze...
# ..                                                 ...
# 667  https://naturalhazards.eu/database, https://ze...
# 668  https://naturalhazards.eu/database, https://ze...
# 669  https://naturalhazards.eu/database, https://ze...
# 670  https://naturalhazards.eu/database, https://ze...
# 671  https://naturalhazards.eu/database, https://ze...
#
#                          flood_name  \
# 0     Flood in France, on 1/20/2020
# 1     Flood in France, on 1/20/2020
# 2      Flood in Spain, on 1/20/2020
# 3      Flood in Spain, on 1/20/2020
# 4      Flood in Spain, on 1/20/2020
# ..                              ...
# 667  Flood in France, on 11/25/2014
# 668   Flood in Spain, on 11/30/2014
# 669   Flood in Greece, on 12/4/2014
# 670   Flood in Greece, on 12/4/2014
# 671   Flood in Greece, on 12/4/2014
#
#                                             flood_info
# 0                Heavy rainfall up to 379 mm in 3 days
# 1                Heavy rainfall up to 379 mm in 3 days
# 2          Storm surge and heavy rainfall up to 227 mm
# 3          Storm surge and heavy rainfall up to 227 mm
# 4          Storm surge and heavy rainfall up to 227 mm
# ..                                                 ...
# 667  Heavy rainfall throughout November, culminatin...
# 668              Extreme rainfall up to 240 mm in 24 h
# 669                Heavy rainfall up to 120 mm in 24 h
# 670                Heavy rainfall up to 120 mm in 24 h
# 671                Heavy rainfall up to 120 mm in 24 h
#
# [672 rows x 23 columns]

# %% [markdown]
# ## Don't fix the hanze dataset for english / coherent version bc it's too much. Rather group by code and fix the names of the top 10 regions

# %%
df_hanze = df_hanze[[
    "id", "flood_name", "flood_info", "year", "country", "start_date", "end_date", "fatalities", "people_affected",
    "nuts3_region", "nuts3_code", "nuts3_region_urban_rural_typology", 
    "nuts3_coastal_regions", "nuts2_region", "nuts2_code", "nuts1_region", "nuts1_code", "cause", "flood_type", 
    "data_exists", "sources", "notes", "reportLink"
]]

# %%
df_hanze.to_excel('df_hanze_final_for_merge_decade.xlsx', index=False)

# %% [markdown]
# # Concatinate, final dataset

# %%
df_copernicus_and_emdat_hanze = pd.concat([df_copernicus_and_emdat, df_hanze], join="outer", ignore_index=True)

# %%
df_copernicus_and_emdat_hanze
# Out:
#           id                                         flood_name  \
# 0    EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 1    EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 2    EMSR773  Flood in Valencian Commynity, Spain on 29 Octo...
# 3    EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# 4    EMSR771  Flood in Emilia- Romagna region, Italy on 20 O...
# ..       ...                                                ...
# 870      271                     Flood in France, on 11/25/2014
# 871     2312                      Flood in Spain, on 11/30/2014
# 872     2130                      Flood in Greece, on 12/4/2014
# 873     2130                      Flood in Greece, on 12/4/2014
# 874     2130                      Flood in Greece, on 12/4/2014
#
#                                             flood_info  year country  \
# 0    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 1    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 2    On 29 October 2024 at 14:30 UTC, an extraordin...  2024   Spain
# 3    Italy has been hit in recent days by a severe ...  2024   Italy
# 4    Italy has been hit in recent days by a severe ...  2024   Italy
# ..                                                 ...   ...     ...
# 870  Heavy rainfall throughout November, culminatin...  2014  France
# 871              Extreme rainfall up to 240 mm in 24 h  2014   Spain
# 872                Heavy rainfall up to 120 mm in 24 h  2014  Greece
# 873                Heavy rainfall up to 120 mm in 24 h  2014  Greece
# 874                Heavy rainfall up to 120 mm in 24 h  2014  Greece
#
#               start_date    end_date  fatalities  people_affected  \
# 0    2024-10-29 14:30:00         NaT       285.0         190090.0
# 1    2024-10-29 14:30:00         NaT       285.0         190090.0
# 2    2024-10-29 14:30:00         NaT       285.0         190090.0
# 3    2024-10-20 12:00:00         NaT         1.0            670.0
# 4    2024-10-20 12:00:00         NaT         1.0            670.0
# ..                   ...         ...         ...              ...
# 870           11/25/2014   12/5/2014         6.0           3000.0
# 871           11/30/2014  11/30/2014         1.0              NaN
# 872            12/4/2014  12/14/2014         5.0              NaN
# 873            12/4/2014  12/14/2014         5.0              NaN
# 874            12/4/2014  12/14/2014         5.0              NaN
#
#                    nuts3_region  ...                nuts2_region nuts2_code  \
# 0            Valencia province   ...             Valencia region       ES52
# 1             Albacete province  ...   Castilla-La Mancha region       ES42
# 2            Castellón province  ...             Valencia region       ES52
# 3        Reggio Emilia province  ...       Emilia-Romagna region       ITH5
# 4               Modena province  ...       Emilia-Romagna region       ITH5
# ..                          ...  ...                         ...        ...
# 870                 Haute-Corse  ...                       Corse       FRM0
# 871                      Girona  ...                    Cataluña       ES51
# 872               Έβρος / Evros  ...  Aνατολική Μακεδονία, Θράκη       EL51
# 873  Θεσσαλονίκη / Thessaloniki  ...          Κεντρική Μακεδονία       EL52
# 874             Κιλκίς / Kilkis  ...          Κεντρική Μακεδονία       EL52
#
#             nuts1_region nuts1_code  \
# 0          Eastern Spain        ES5
# 1          Central Spain        ES4
# 2          Eastern Spain        ES5
# 3    North-Eastern Italy        ITH
# 4    North-Eastern Italy        ITH
# ..                   ...        ...
# 870                Corse        FRM
# 871                 Este        ES5
# 872        Βόρεια Ελλάδα        EL5
# 873        Βόρεια Ελλάδα        EL5
# 874        Βόρεια Ελλάδα        EL5
#
#                                                  cause flood_type data_exists  \
# 0                                                 None       None  copernicus
# 1                                                 None       None  copernicus
# 2                                                 None       None  copernicus
# 3                                                 None       None  copernicus
# 4                                                 None       None  copernicus
# ..                                                 ...        ...         ...
# 870  Heavy rainfall throughout November, culminatin...      River       HANZE
# 871              Extreme rainfall up to 240 mm in 24 h      Flash       HANZE
# 872                Heavy rainfall up to 120 mm in 24 h      River       HANZE
# 873                Heavy rainfall up to 120 mm in 24 h      River       HANZE
# 874                Heavy rainfall up to 120 mm in 24 h      River       HANZE
#
#                                                sources notes  \
# 0                       Copernicus, GDACS ID FL1102983   NaN
# 1                       Copernicus, GDACS ID FL1102983   NaN
# 2                       Copernicus, GDACS ID FL1102983   NaN
# 3                       Copernicus, GDACS ID FL1102961   NaN
# 4                       Copernicus, GDACS ID FL1102961   NaN
# ..                                                 ...   ...
# 870  HANZE (CRED (2023); Brakenridge (2022); Meteo ...   NaN
# 871  HANZE (Papagiannaki et al. (2022); Noticias de...   NaN
# 872  HANZE (Papagiannaki et al. (2022); Brakenridge...   NaN
# 873  HANZE (Papagiannaki et al. (2022); Brakenridge...   NaN
# 874  HANZE (Papagiannaki et al. (2022); Brakenridge...   NaN
#
#                                             reportLink
# 0    https://storymaps.arcgis.com/stories/9ff57e932...
# 1    https://storymaps.arcgis.com/stories/9ff57e932...
# 2    https://storymaps.arcgis.com/stories/9ff57e932...
# 3    https://storymaps.arcgis.com/stories/b95e2210e...
# 4    https://storymaps.arcgis.com/stories/b95e2210e...
# ..                                                 ...
# 870  https://naturalhazards.eu/database, https://ze...
# 871  https://naturalhazards.eu/database, https://ze...
# 872  https://naturalhazards.eu/database, https://ze...
# 873  https://naturalhazards.eu/database, https://ze...
# 874  https://naturalhazards.eu/database, https://ze...
#
# [875 rows x 23 columns]

# %%
df_copernicus_and_emdat_hanze.to_excel("decade_final_dataset_copernicus_emdat_hanze.xlsx", index=True)
