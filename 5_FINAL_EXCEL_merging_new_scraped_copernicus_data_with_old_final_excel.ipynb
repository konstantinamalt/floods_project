# %% [markdown]
# ### 15 february merging to see what is different what you lost after copernicus corrected their data

# %%
import pandas as pd

# %% [markdown]
# ### the dataset below has translated NUTS regions that were done manually

# %%
df = pd.read_excel("final_all_aois_details_WITH_NUTS_TRANSLATED.xlsx")
df
# Out:
#      activation_code                             event_name  \
# 0            EMSR773        Flood in Valencia Region, Spain
# 1            EMSR773        Flood in Valencia Region, Spain
# 2            EMSR773        Flood in Valencia Region, Spain
# 3            EMSR773        Flood in Valencia Region, Spain
# 4            EMSR773        Flood in Valencia Region, Spain
# ...              ...                                    ...
# 1696         EMSR657  Flood in Daugava River valley, Latvia
# 1697         EMSR657  Flood in Daugava River valley, Latvia
# 1698         EMSR657  Flood in Daugava River valley, Latvia
# 1699         EMSR657  Flood in Daugava River valley, Latvia
# 1700         EMSR657  Flood in Daugava River valley, Latvia
#
#                                                  reason  \
# 0     On 29 October 2024 at 14:30 UTC, an extraordin...
# 1     On 29 October 2024 at 14:30 UTC, an extraordin...
# 2     On 29 October 2024 at 14:30 UTC, an extraordin...
# ...

# %%
scraped_data = pd.read_excel("final_scraped_data.xlsx")
scraped_data
# Out:
#      activation_code         aoiName  aoiNumber type  monitoring  \
# 0            EMSR775           Olden          1  DEL           0
# 1            EMSR775           Oyane          2  DEL           0
# 2            EMSR775           Oyane          2  DEL           1
# 3            EMSR775  Aurlandsvangen          3  DEL           0
# 4            EMSR775      Over Ardal          4  DEL           0
# ...              ...             ...        ...  ...         ...
# 7666         EMSR657    DaugavaRiver          1  DEL           5
# 7667         EMSR657    DaugavaRiver          1  DEL           5
# 7668         EMSR657    DaugavaRiver          1  DEL           5
# 7669         EMSR657    DaugavaRiver          1  DEL           5
# 7670         EMSR657    DaugavaRiver          1  DEL           5
#
#              deliveryTime                            subcategory_unit  \
# 0     2024-11-01T14:12:00                                         NaN
# ...

# %%
df_combined = pd.concat([df, scraped_data], ignore_index=True)
df_combined
# Out:
#      activation_code                       event_name  \
# 0            EMSR773  Flood in Valencia Region, Spain
# 1            EMSR773  Flood in Valencia Region, Spain
# 2            EMSR773  Flood in Valencia Region, Spain
# 3            EMSR773  Flood in Valencia Region, Spain
# 4            EMSR773  Flood in Valencia Region, Spain
# ...              ...                              ...
# 9367         EMSR657                              NaN
# 9368         EMSR657                              NaN
# 9369         EMSR657                              NaN
# 9370         EMSR657                              NaN
# 9371         EMSR657                              NaN
#
#                                                  reason  \
# 0     On 29 October 2024 at 14:30 UTC, an extraordin...
# 1     On 29 October 2024 at 14:30 UTC, an extraordin...
# 2     On 29 October 2024 at 14:30 UTC, an extraordin...
# 3     On 29 October 2024 at 14:30 UTC, an extraordin...
# ...

# %%
df_combined.to_excel('merged_final_with_nuts_translated_to_new_scraped_data.xlsx', index=False)

# %% [markdown]
# ### Now that you checked, clean the scrape data leave the old, and then fill up manually the blanks in the other columns

# %%
df_clean = pd.read_excel("merged_final_with_nuts_translated_to_new_scraped_data.xlsx")
df_clean
# Out:
#      activation_code event_name reason activator eventTime activationTime  \
# 0            EMSR775        NaN    NaN       NaN       NaN            NaN
# 1            EMSR775        NaN    NaN       NaN       NaN            NaN
# 2            EMSR775        NaN    NaN       NaN       NaN            NaN
# 3            EMSR775        NaN    NaN       NaN       NaN            NaN
# 4            EMSR775        NaN    NaN       NaN       NaN            NaN
# ...              ...        ...    ...       ...       ...            ...
# 9367         EMSR657        NaN    NaN       NaN       NaN            NaN
# 9368         EMSR657        NaN    NaN       NaN       NaN            NaN
# 9369         EMSR657        NaN    NaN       NaN       NaN            NaN
# 9370         EMSR657        NaN    NaN       NaN       NaN            NaN
# 9371         EMSR657        NaN    NaN       NaN       NaN            NaN
#
#      countries       aoiName  aoiNumber type  ...  nuts3_2024_coastal_regions  \
# ...

# %%
df_final_clean = df_clean[df_clean['data'] == 'final excel']
df_final_clean
# Out:
#      activation_code                             event_name  \
# 36           EMSR773                                    NaN
# 38           EMSR773                                    NaN
# 43           EMSR773                                    NaN
# 44           EMSR773                                    NaN
# 46           EMSR773                                    NaN
# ...              ...                                    ...
# 9339         EMSR657  Flood in Daugava River valley, Latvia
# 9347         EMSR657  Flood in Daugava River valley, Latvia
# 9355         EMSR657  Flood in Daugava River valley, Latvia
# 9360         EMSR657  Flood in Daugava River valley, Latvia
# 9364         EMSR657  Flood in Daugava River valley, Latvia
#
#                                                  reason  \
# 36                                                  NaN
# 38                                                  NaN
# 43                                                  NaN
# ...

# %% [markdown]
# ### you dont need thew total column

# %%
df_final_clean = df_final_clean.drop(columns=['total'])
df_final_clean
# Out:
#      activation_code                             event_name  \
# 36           EMSR773                                    NaN
# 38           EMSR773                                    NaN
# 43           EMSR773                                    NaN
# 44           EMSR773                                    NaN
# 46           EMSR773                                    NaN
# ...              ...                                    ...
# 9339         EMSR657  Flood in Daugava River valley, Latvia
# 9347         EMSR657  Flood in Daugava River valley, Latvia
# 9355         EMSR657  Flood in Daugava River valley, Latvia
# 9360         EMSR657  Flood in Daugava River valley, Latvia
# 9364         EMSR657  Flood in Daugava River valley, Latvia
#
#                                                  reason  \
# 36                                                  NaN
# 38                                                  NaN
# 43                                                  NaN
# ...

# %%
df_final_clean.to_excel("FINAL_aois_all_details_nuts_translated.xlsx", index=False)

# %% [markdown]
# ## manually cleaned and checked the above file and renamed it: CLEAN_FINAL_aois_all_details_nuts_translated

# %% [markdown]
# ## this is the final dataset for copernicus data
